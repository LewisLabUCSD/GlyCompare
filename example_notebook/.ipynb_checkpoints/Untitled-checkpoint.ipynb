# %%
# building EPO


import pandas as pd

# %%
mgat4a4b=pd.read_excel(r'/Users/apple/Desktop/NathanLab/GlyCompare_submission_all/Appeal/Synthesis Network Information.xlsx', sheet_name='mgat4a4b')
mgat4a4b5=pd.read_excel(r'/Users/apple/Desktop/NathanLab/GlyCompare_submission_all/Appeal/Synthesis Network Information.xlsx', sheet_name='mgat4a4b5')
mgat5=pd.read_excel(r'/Users/apple/Desktop/NathanLab/GlyCompare_submission_all/Appeal/Synthesis Network Information.xlsx', sheet_name='mgat5')
wt=pd.read_excel(r'/Users/apple/Desktop/NathanLab/GlyCompare_submission_all/Appeal/Synthesis Network Information.xlsx', sheet_name='WT')
st3gal4=pd.read_excel(r'/Users/apple/Desktop/NathanLab/GlyCompare_submission_all/Appeal/Synthesis Network Information.xlsx', sheet_name='st3gal46')

# %%
st3gal4
# Out:
#                                             StartNodes  \
# 0    '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(Ab4GNb3Ab4GNb3Ab...
# 1    '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(Ab4GNb3Ab4GNb6)M...
# 2    '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(Ab4GNb3Ab4GNb6)M...
# 3    '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(Ab4GNb3Ab4GNb6)M...
# 4    '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(Ab4GNb6)Ma6)Mb4G...
# 5    '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(Ab4GNb6)Ma6)Mb4G...
# 6    '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(Ab4GNb6)Ma6)Mb4G...
# 7    '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(GNb3Ab4GNb3Ab4GN...
# 8    '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(GNb3Ab4GNb3Ab4GN...
# 9    '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(GNb3Ab4GNb3Ab4GN...
# 10   '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(GNb3Ab4GNb6)Ma6)...
# 11   '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(GNb3Ab4GNb6)Ma6)...
# 12   '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(GNb3Ab4GNb6)Ma6)...
# 13   '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(GNb6)Ma6)Mb4GNb4...
# 14   '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(GNb6)Ma6)Mb4GNb4...
# 15   '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(GNb6)Ma6)Mb4GNb4...
# ...

# %%
for i in ['mgat4a4b', 'mgat4a4b5', 'mgat5', 'WT']:
    b=pd.read_excel(r'/Users/apple/Desktop/NathanLab/GlyCompare_submission_all/Appeal/Synthesis Network Information.xlsx',sheet_name=i)
    b[['StartNodes','EndNodes']].to_csv(r'/Users/apple/Desktop/NathanLab/GlyCompare_submission_all/Appeal/network_'+i+'.csv')
    a = sorted(list(set(list(b['StartNodes'])+list(b['EndNodes']))))
    c=[]
    for k in a:
        if k in list(b['Annotated Glycans']):
            c.append('Y')
        else:
            c.append('N')
    pd.DataFrame([list(a),c]).transpose().to_csv(r'/Users/apple/Desktop/NathanLab/GlyCompare_submission_all/Appeal/network_nodes_attri_'+i+'.csv')

# %%
d.to_csv('/Users/apple/Desktop/NathanLab/GlyCompare_submission_all/Appeal/wt_4a4b.csv')

# %%
b=pd.read_excel(r'/Users/apple/Desktop/NathanLab/GlyCompare_submission_all/Appeal/Synthesis Network Information.xlsx',sheet_name='WT')
# b[['StartNodes','EndNodes']].to_csv(r'/Users/apple/Desktop/NathanLab/GlyCompare_submission_all/Appeal/network_'+i+'.csv')
c=pd.read_excel(r'/Users/apple/Desktop/NathanLab/GlyCompare_submission_all/Appeal/Synthesis Network Information.xlsx',sheet_name='mgat4a4b')

d = pd.concat([b[['StartNodes','EndNodes']],c[['StartNodes','EndNodes']]]).drop_duplicates().reset_index(drop=True)
a = sorted(list(set(list(d['StartNodes'])+list(d['EndNodes']))))
a_wt = sorted(list(set(list(b['StartNodes'])+list(b['EndNodes']))))
nodes_dict = {'name':a}
for i in ['mgat4a4b', 'WT', 'st3gal46']:
    c = []
    b = pd.read_excel(r'/Users/apple/Desktop/NathanLab/GlyCompare_submission_all/Appeal/Synthesis Network Information.xlsx',sheet_name=i)
    for k in a:
        if k in list(b['Annotated Glycans']):
            print(i, k)
            c.append('Y')
        else:
            c.append('N')
    nodes_dict[i]=c
    c=[]
    for k in a:
        if k in a_wt:
            if k in list(b['StartNodes']) or k in list(b['EndNodes']):
                c.append('Y')
            else:
                c.append('N')
        else:
            c.append('N')
    nodes_dict[i+'_substr']=c

pd.DataFrame(nodes_dict).to_csv(r'/Users/apple/Desktop/NathanLab/GlyCompare_submission_all/Appeal/network_two_nodes_attri_'+i+'.csv')
# Out:
# mgat4a4b '(Ab4GNb2Ma3(Ab4GNb2Ma6)Mb4GNb4(Fa6)GN);Asn'
# mgat4a4b '(Ab4GNb2Ma3(NNa3Ab4GNb2(NNa3Ab4GNb3Ab4GNb6)Ma6)Mb4GNb4(Fa6)GN);Asn'
# mgat4a4b '(Ab4GNb2Ma3(NNa3Ab4GNb2Ma6)Mb4GNb4(Fa6)GN);Asn'
# mgat4a4b '(NNa3Ab4GNb2Ma3(NNa3Ab4GNb2(NNa3Ab4GNb3Ab4GNb6)Ma6)Mb4GNb4(Fa6)GN);Asn'
# mgat4a4b '(NNa3Ab4GNb2Ma3(NNa3Ab4GNb2(NNa3Ab4GNb6)Ma6)Mb4GNb4GN);Asn'
# mgat4a4b '(NNa3Ab4GNb2Ma3(NNa3Ab4GNb2Ma6)Mb4GNb4(Fa6)GN);Asn'
# WT '(Ab4GNb2(Ab4GNb4)Ma3(NNa3Ab4GNb2(NNa3Ab4GNb6)Ma6)Mb4GNb4(Fa6)GN);Asn'
# WT '(Ab4GNb2(NNa3Ab4GNb4)Ma3(NNa3Ab4GNb2(NNa3Ab4GNb6)Ma6)Mb4GNb4(Fa6)GN);Asn'
# WT '(Ab4GNb2(NNa3Ab4GNb4)Ma3(NNa3Ab4GNb2Ma6)Mb4GNb4(Fa6)GN);Asn'
# WT '(Ab4GNb2Ma3(Ab4GNb2Ma6)Mb4GNb4(Fa6)GN);Asn'
# WT '(Ab4GNb2Ma3(NNa3Ab4GNb2Ma6)Mb4GNb4(Fa6)GN);Asn'
# WT '(NNa3Ab4GNb2(NNa3Ab4GNb4)Ma3(NNa3Ab4GNb2(NNa3Ab4GNb3Ab4GNb3Ab4GNb6)Ma6)Mb4GNb4(Fa6)GN);Asn'
# WT '(NNa3Ab4GNb2(NNa3Ab4GNb4)Ma3(NNa3Ab4GNb2(NNa3Ab4GNb3Ab4GNb6)Ma6)Mb4GNb4(Fa6)GN);Asn'
# ...

# %%
d
# Out:
#                                              StartNodes  \
# 0     '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(Ab4GNb3Ab4GNb3Ab...
# 1     '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(Ab4GNb3Ab4GNb3Ab...
# 2     '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(Ab4GNb3Ab4GNb3Ab...
# 3     '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(Ab4GNb3Ab4GNb3Ab...
# 4     '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(Ab4GNb3Ab4GNb3Ab...
# 5     '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(Ab4GNb3Ab4GNb3Ab...
# 6     '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(Ab4GNb3Ab4GNb3Ab...
# 7     '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(Ab4GNb3Ab4GNb3Ab...
# 8     '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(Ab4GNb3Ab4GNb3Ab...
# 9     '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(Ab4GNb3Ab4GNb6)M...
# 10    '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(Ab4GNb3Ab4GNb6)M...
# 11    '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(Ab4GNb3Ab4GNb6)M...
# 12    '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(Ab4GNb3Ab4GNb6)M...
# 13    '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(Ab4GNb3Ab4GNb6)M...
# 14    '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(Ab4GNb3Ab4GNb6)M...
# 15    '(Ab4GNb2(Ab4GNb4)Ma3(Ab4GNb2(Ab4GNb3Ab4GNb6)M...
# ...
