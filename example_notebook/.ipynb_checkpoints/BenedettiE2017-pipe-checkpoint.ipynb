# %% [markdown]
# ## Network inference from glycoproteomics data reveals new reactions in the IgG glycosylation pathway.
# ## https://www.ncbi.nlm.nih.gov/pubmed/29133956

# %% [markdown]
# # for each one generate different substructure abundance table

# %%
import sys
# please insert the glycompare to the PATH
sys.path.insert(0, '/Users/apple/PycharmProjects/GlyCompare/')
import pandas as pd
import glycompare
import os

from glycompare import *
import glypy
from importlib import reload
# Out:
# Thanks for using the GlyCompare v1.1,
# Please check our github for the latest update.
#
#
# Bokan & Ben,
# 10/2/2019

# %%
file_addr='/Users/apple/Desktop/NathanLab/glycan_data/SupplementalMaterial_DatasetS1_PreprocessedData.xls'
k_2013 = pd.read_excel(file_addr, sheet_name='Korčula2013', header=0, index_col=0)
k_2010 = pd.read_excel(file_addr, sheet_name='Korčula2010', header=0, index_col=0)
vis = pd.read_excel(file_addr, sheet_name='Vis', header=0, index_col=0)
split = pd.read_excel(file_addr, sheet_name='Split', header=0, index_col=0)

# %%
import numpy as np
# np.exp(k_2013)

# %%
# k_2013 = pd.read_csv('/Users/apple/Desktop/NathanLab/glycan_data/Korčula2013.txt', header=0, sep='\t', index_col=0)
# k_2010 = pd.read_csv('/Users/apple/Desktop/NathanLab/glycan_data/Korčula2010.txt', header=0, sep='\t', index_col=0)
# split = pd.read_csv('/Users/apple/Desktop/NathanLab/glycan_data/Split.txt', header=0, sep='\t', index_col=0)
# vis = pd.read_csv('/Users/apple/Desktop/NathanLab/glycan_data/Vis.txt', header=0, sep='\t', index_col=0)

# %%
group_1 = []
group_2 = []
group_4 = []
group_id_1 = []
group_id_2 = []
group_id_4 = []

for i in k_2013.columns:
    x,y = i.split('_')
    if i.find('IgG1') != -1:
        group_id_1.append(i)
        group_1.append(y)
    elif i.find('IgG2') != -1:
        group_id_2.append(i)
        group_2.append(y)
    elif i.find('IgG4') != -1:
        group_id_4.append(i)
        group_4.append(y)
    else:
        print(i)
table_list=[]
output_name_ = []
data_name_list = ['k_2010', 'k_2013', 'split', 'vis']
ig_name_list = ['group_1', 'group_2', 'group_4']
# ig_table_list = [group_1, group_2, group_4]

for idex, i in enumerate([k_2010, k_2013, split, vis]):
    for jdex, j in enumerate([group_id_1, group_id_2, group_id_4]):
        _table = i[j]
        
        _table.columns = [k.split('_')[1] for k in _table[j].columns]
        table_list.append(_table)

        output_name_.append(data_name_list[idex]+'_'+ig_name_list[jdex])

# %%
import os
from importlib import reload

import pandas as pd
import seaborn as sns
from scipy.stats import zscore

from glycompare import *
import matplotlib.pyplot as plt
from copy import deepcopy
# reload(pipeline_functions)
# %matplotlib inline

# %%
# parameter setting 
# environment parameter setting 
glycompare_addr = '/Users/apple/PycharmProjects/GlyCompare/'
# glytoucan_db_addr = os.path.join(glycompare_addr, 'glycompare','database', 'glytoucan_database.json')
# __init__.num_processors = 4
# __init__.exact_Ture = False
linkage_specific = True
num_processors = 8
# project parameter
working_addr = '/Users/apple/PycharmProjects/GlyCompare/example_data/BE2017/'

# %%
def _parse_edge_attri_to_table(edge_dict):
#     edge_start=[]
#     edge_end = []
        edge_attri_dict = {'start':[], 'end':[]}
        _attributes_checked = False
        for _nodes in edge_dict:
            for _sub_nodes in edge_dict[_nodes]:
                if not _attributes_checked:
                    for _key in edge_dict[_nodes][_sub_nodes]:
                        edge_attri_dict[_key] = []
                    _attributes_checked=True
                for _key in edge_dict[_nodes][_sub_nodes]:
    #                 print(_nodes, _sub_nodes, edge_dict[_nodes][_sub_nodes][_key])
                    edge_attri_dict[_key].append(edge_dict[_nodes][_sub_nodes][_key])
                edge_attri_dict['start'].append(_nodes)
                edge_attri_dict['end'].append(_sub_nodes)
        return edge_attri_dict

# %%
# working_addr
for idex, i in enumerate(table_list):
#     print(working_addr+output_name_[idex]+'_log.csv')
    i.to_csv(working_addr+'/source_data/'+output_name_[idex]+'_log.csv')
    np.exp(i).to_csv(working_addr+'/source_data/'+output_name_[idex]+'_exp.csv')

# %%
# pipeline_functions.check_init_dir(keywords_dict)
reload(glycan_io)
reload(process_glycoprofiles)
reload(pipeline_functions)

glycan_dict = glycan_io.load_glycan_dict_from_json('/Users/apple/PycharmProjects/GlyCompare/example_data/BE2017/glycan_glycoct_dict.json')
for absolute in [True, False]:
    if absolute:
        abs_pref = '_abs'
    else:
        abs_pref = '_rel'
    for exp in [True, False]:
        if exp:
            exp_pref = '_exp'
        else:
            exp_pref = '_log'
        for i in output_name_:
            project_name = i+exp_pref+abs_pref
            costumized_glycan_identifier = False
            external_profile_naming= False
        #     reload(pipeline_functions)

            # initiator
            keywords_dict = pipeline_functions.load_para_keywords(project_name, working_addr, )
        #     keywords_dict
        #     data_name_ = ['k_2010_group_1.csv','k_2010_group_2.csv','k_2010_group_4.csv']
            meta_name = []
            abd_table = pd.read_csv(os.path.join(working_addr,'source_data',i+exp_pref+'.csv'), sep=',', index_col=0)
            meta_name.extend(list(abd_table.columns))
            meta_name = set(meta_name)

            data_type = 'glycan_dict'
            glycan_dict = pipeline_functions.load_glycans_pip(keywords_dict=keywords_dict,
                                                       data_type=data_type, 
                                                       structure_loader=glycan_dict, forced=False)
            glycan_substructure_occurance_dict = pipeline_functions.extract_and_merge_substrutures_pip(keywords_dict, 
                                                                             num_processors=num_processors,
                                                                             linkage_specific=linkage_specific, 
                                                                             forced=False)

            substructure_glycoct_dict_addr = keywords_dict['substructure_glycoct_dict_addr']
            substructure_dict = glycan_io.load_substructure_vec_from_json(substructure_glycoct_dict_addr)
            _substructure_lab = select_motifs.substructureLabwithCore(substructure_=substructure_dict,
                                                                glycan_core=substructure_dict[108],
                                                                linkage_specific=linkage_specific)  # unicarbkb_substructures_12259.json

            _substructure_lab.get_dependence_tree_core()



        #     abd_table = glycan_io.load_table(os.path.join(keywords_dict['source_dir'], i+'.csv'))
            abd_table = abd_table.transpose()
            _, glycoprofile_list = pipeline_functions.glycoprofile_pip(keywords_dict, 
                                                                       abd_table, 
                                                                       unique_glycan_identifier_to_structure_id=True, 
                                                                       already_glytoucan_id=True,
                                                                       external_profile_naming=False, 
                                                                       absolute=absolute,
                                                                       forced=True)

            reload(pipeline_functions)
            core = substructure_dict[108]
            substructure_glycoct_dict_addr = keywords_dict['substructure_glycoct_dict_addr']
            # assert os.path.isfile(substructure_glycoct_dict_addr), 'missing ' + substructure_glycoct_dict_addr
            substructure_abd_table_addr = keywords_dict['substructure_abd_table_addr']
            substructure_abd_table = pd.read_csv(substructure_abd_table_addr, index_col=0)
            substructure_dict = glycan_io.load_substructure_vec_from_json(substructure_glycoct_dict_addr)
            # _substructure_lab = select_substructures.substructureLabwithCore(substructure_dict, glycan_core=select_substructures.nglycan_core, linkage_specific=False)  # unicarbkb_substructures_12259.json
            # _substructure_lab.get_dependence_tree_core()

            # if not select_col:
            select_col = substructure_abd_table.columns
            _substructure_lab = select_motifs.substructureLabwithCore(substructure_=substructure_dict,
                                                                glycan_core=core,
                                                                linkage_specific=linkage_specific)  # unicarbkb_substructures_12259.json
            _substructure_lab.get_dependence_tree_core()
            a_node_state = select_motifs.NodesState(dependence_tree=_substructure_lab.substructure_dep_tree_core,
                                                            substructure_weight=select_motifs.get_weight_dict(
                                                                substructure_abd_table[select_col]),
                                                            linkage_specific=linkage_specific)
            node_attri, edge_attri, mod_nodes, mod_edges, merged_weights_dict = a_node_state.nodes_dropping_pipe(
            drop_parellel=False, drop_diff_abund=False)
            print('_substructure_lab.core_index',_substructure_lab.core_index)
            # if _substructure_lab.core_index in mod_nodes:
            #         mod_nodes.remove(_substructure_lab.core_index)
            #         print("Removed core, the index is", _substructure_lab.core_index)
            motif_dict = {}
            for i in mod_nodes:
                motif_dict[i] = _substructure_lab.substructure_vec[i]
            glycan_io.output_glycan_dict_to_glycoct_dict(motif_dict, keywords_dict['motif_glycoct_dict_addr'])

            motif_abd_table = substructure_abd_table[select_col][substructure_abd_table.index.isin(mod_nodes)]
            motif_abd_table_addr = keywords_dict['motif_abd_table_addr']
            motif_abd_table.to_csv(motif_abd_table_addr)

            for i in mod_nodes:
                plot_glycan_utilities.plot_glycan(_substructure_lab.substructure_vec[i], 
                                                  title=i, 
                                                  label=True,
                                                  addr=keywords_dict['plot_output_dir'] + 'motif_'+str(i)+'.eps')
        #     plt.savefig()
        #     print(keywords_dict['plot_output_dir'] + 'motif_'+str(i)+'.eps')
            index_list = sorted(list(node_attri.keys()))
            keep_list = [node_attri[i]['kept'] for i in index_list]
            from glypy.algorithms.subtree_search.inclusion import subtree_of

            motif_glycan_mapping = []
            for i in index_list:
                if i in mod_nodes: 
                    found=False
                    for j in glycan_dict:
                        if subtree_of(_substructure_lab.substructure_vec[i], glycan_dict[j], exact=True) ==1 \
                            and subtree_of(glycan_dict[j], _substructure_lab.substructure_vec[i],  exact=True) ==1:
                            print(i,j, found)
                            found=True
                            break
                    if found:
                        motif_glycan_mapping.append(j)
                    else:
                        motif_glycan_mapping.apend('N')

                else:
                    motif_glycan_mapping.append('N')
            # motif_glycan_mapping
            pd.DataFrame(data={'index':index_list, 'keep':keep_list, 'if_glycan':motif_glycan_mapping}).to_csv(keywords_dict['output_data_dir']+project_name+'_node_list.csv')


            pd.DataFrame(_parse_edge_attri_to_table(edge_attri)).to_csv(keywords_dict['output_data_dir']+project_name+'_edge_list.csv')
# Out:
# Check if the required files exist
# files checked
# Check if the required files exist
# files checked
# Successfully created the directory need, please add the source file is the directory
# Saved /Users/apple/PycharmProjects/GlyCompare/example_data/BE2017/output_data/k_2010_group_1_log_rel_glycan_glycoct_dict.json for future use. You can use "used" in the datatype next time
# start parallel parsing 20 glycans
# start G0F
# start G1FN
# start G1N
# start G2FN
# start G0FN
# start G2NS
# start G2N
# start G1NS
# G0F 8 0.2524738311767578
# start G2
# G0FN 9 0.5626459121704102
# start G1S
# G1N 9 0.6340982913970947
# start G1
# G2 9 0.4113028049468994
# start G2FS
# G1 8 0.24032878875732422
# G2N 10 0.9350528717041016
# start G0
# start G2FNS
# G1FN 10 1.0565719604492188
# start G2S
# G1NS 10 1.093621015548706
# start G1FS
# G0 7 0.10987710952758789
# start G1FNS
# G1S 9 0.4833700656890869
# start G2F
# G2FN 11 1.506269931793213
# start G0N
# G2NS 11 3.2340338230133057
# G1FS 10 2.0660488605499268
# G2S 10 2.123873710632324
# G2F 10 2.0686428546905518
# start G1F
# G2FS 11 2.6003787517547607
# G1FNS 11 2.1843578815460205
# G0N 8 0.19736504554748535
# G2FNS 12 2.344848871231079
# G1F 9 0.3984959125518799
# finished pool
# glycan_dict 20
# start glycan_substructure_dict
# loaded existed substructure_dic
# start merge substructure_dict
# Start merge_glycan_substructure_to_substructure_dict
# combine original
# substructure_dict is merged with len  1856
# finished removing duplicate
# after the cleaning the substructure vec's length is 202
# 1 7
# 2 10
# 3 13
# 4 18
# 5 24
# 6 30
# 7 32
# 8 29
# 9 21
# 10 12
# 11 5
# 12 1
# 202
# finished merge substructure_dic
# 1 7
# 2 10
# 3 13
# 4 18
# 5 24
# 6 30
# 7 32
# 8 29
# 9 21
# 10 12
# 11 5
# 12 1
# 202
# get substructure vec, the length is  202
# start processing G2FN
# start processing G0F
# start processing G1FN
# start processing G2N
# start processing G0FN
# start processing G1N
# start processing G2NS
# start processing G1NS
# start processing G2
# start processing G1S
# start processing G1
# start processing G2FS
# start processing G0
# start processing G2FNS
# start processing G2S
# start processing G1FS
# start processing G1FNS
# start processing G2F
# start processing G0N
# start processing G1F
# closing poll
# joining pool
# finished  1
# finished  3
# finished  8
# finished  5
# finished  4
# finished  2
# finished  0
# finished  9
# finished  7
# finished  6
# finished  10
# finished  12
# finished  11
# finished  14
# finished  17
# finished  15
# finished  16
# finished  18
# finished  19
# finished  13
# converting dict
# finished glycan deconvolution
# the glycan core is
# start substructure_with core
# len 7
# len 8
# len 9
# len 10
# len 11
# len 12
# Finish the n-glycan match  28  substructures are matched to the n-glycan core
# start building dependence_tree
# 7
# 8
# 9
# 10
# 11
# 12
# abd_list 20 profile_list 504
# 20 504
# no external profile naming found
# the glycan core is
# start substructure_with core
# len 7
# len 8
# len 9
# len 10
# len 11
# len 12
# Finish the n-glycan match  28  substructures are matched to the n-glycan core
# start building dependence_tree
# 7
# 8
# 9
# 10
# 11
# 12
# Start dropping nodes with weight zero, nodes count: 28
# Nodes left []
# 28 60
# _a.nodes 28
# _a.nodes 28
# merged_weights_dict 28
# After first drop 8 + 20 =  28 28.0
# mod_nodes 20
# mod_edges 36
# _substructure_lab.core_index 108
# 108 G0 False
# 139 G1 False
# 148 G0N False
# 154 G0F False
# 164 G2 False
# 165 G1S False
# 173 G1N False
# 176 G1F False
# 182 G0FN False
# 184 G2S False
# 187 G2N False
# 188 G1NS False
# 189 G2F False
# 190 G1FS False
# 195 G1FN False
# 196 G2NS False
# 197 G2FS False
# 199 G2FN False
# 200 G1FNS False
# 201 G2FNS False
# Check if the required files exist
# files checked
# Check if the required files exist
# files checked
# Successfully created the directory need, please add the source file is the directory
# Saved /Users/apple/PycharmProjects/GlyCompare/example_data/BE2017/output_data/k_2010_group_2_log_rel_glycan_glycoct_dict.json for future use. You can use "used" in the datatype next time
# start parallel parsing 20 glycans
# start G0F
# start G2FN
# start G2N
# start G1FN
# start G2NS
# start G1N
# start G0FN
# start G1NS
# G0F 8 0.28575611114501953
# start G2
# G1N 9 0.532987117767334
# start G1S
# G0FN 9 0.5792138576507568
# G2 9 0.6939167976379395
# start G1
# start G2FS
# G1NS 10 1.0752177238464355
# start G0
# G1FN 10 1.0461013317108154
# start G2FNS
# G2N 10 1.1544291973114014
# start G2S
# G1 8 0.8184661865234375
# start G1FS
# G2FN 11 1.2956161499023438
# start G1FNS
# G0 7 0.19242477416992188
# G2NS 11 1.3794093132019043
# start G2F
# start G0N
# G1S 9 1.0487916469573975
# start G1F
# G0N 8 0.3001852035522461
# G1F 9 0.7252678871154785
# G2S 10 0.9845330715179443
# G1FS 10 0.961266040802002
# G2F 10 0.8438971042633057
# G2FS 11 1.8671109676361084
# G1FNS 11 1.192662000656128
# G2FNS 12 1.7923698425292969
# finished pool
# glycan_dict 20
# start glycan_substructure_dict
# loaded existed substructure_dic
# start merge substructure_dict
# Start merge_glycan_substructure_to_substructure_dict
# combine original
# substructure_dict is merged with len  1856
# finished removing duplicate
# after the cleaning the substructure vec's length is 202
# 1 7
# 2 10
# 3 13
# 4 18
# 5 24
# 6 30
# 7 32
# 8 29
# 9 21
# 10 12
# 11 5
# 12 1
# 202
# finished merge substructure_dic
# 1 7
# 2 10
# 3 13
# 4 18
# 5 24
# 6 30
# 7 32
# 8 29
# 9 21
# 10 12
# 11 5
# 12 1
# 202
# get substructure vec, the length is  202
# start processing G2FN
# start processing G0F
# start processing G1FN
# start processing G2N
# start processing G0FN
# start processing G1N
# start processing G2NS
# start processing G1NS
# start processing G2
# start processing G1S
# start processing G1
# start processing G2FS
# start processing G0
# start processing G2FNS
# start processing G2S
# start processing G1FS
# start processing G1FNS
# start processing G2F
# start processing G0N
# start processing G1F
# closing poll
# joining pool
# finished  1
# finished  3
# finished  0
# finished  5
# finished  4
# finished  2
# finished  6
# finished  8
# finished  9
# finished  7
# finished  12
# finished  10
# finished  11
# finished  19
# finished  14
# finished  15
# finished  17
# finished  18
# finished  13
# finished  16
# converting dict
# finished glycan deconvolution
# the glycan core is
# start substructure_with core
# len 7
# len 8
# len 9
# len 10
# len 11
# len 12
# Finish the n-glycan match  28  substructures are matched to the n-glycan core
# start building dependence_tree
# 7
# 8
# 9
# 10
# 11
# 12
# abd_list 20 profile_list 504
# 20 504
# no external profile naming found
# the glycan core is
# start substructure_with core
# len 7
# len 8
# len 9
# len 10
# len 11
# len 12
# Finish the n-glycan match  28  substructures are matched to the n-glycan core
# start building dependence_tree
# 7
# 8
# 9
# 10
# 11
# 12
# Start dropping nodes with weight zero, nodes count: 28
# Nodes left []
# 28 60
# _a.nodes 28
# _a.nodes 28
# merged_weights_dict 28
# After first drop 8 + 20 =  28 28.0
# mod_nodes 20
# mod_edges 36
# _substructure_lab.core_index 108
# 108 G0 False
# 139 G1 False
# 148 G0N False
# 154 G0F False
# 164 G2 False
# 165 G1S False
# 173 G1N False
# 176 G1F False
# 182 G0FN False
# 184 G2S False
# 187 G2N False
# 188 G1NS False
# 189 G2F False
# 190 G1FS False
# 195 G1FN False
# 196 G2NS False
# 197 G2FS False
# 199 G2FN False
# 200 G1FNS False
# 201 G2FNS False
# Check if the required files exist
# files checked
# Check if the required files exist
# files checked
# Successfully created the directory need, please add the source file is the directory
# Saved /Users/apple/PycharmProjects/GlyCompare/example_data/BE2017/output_data/k_2010_group_4_log_rel_glycan_glycoct_dict.json for future use. You can use "used" in the datatype next time
# start parallel parsing 20 glycans
# start G2FN
# start G0F
# start G1FN
# start G2N
# start G0FN
# start G1N
# start G2NS
# start G1NS
# G0F 8 0.3805859088897705
# start G2
# G0FN 9 0.7259509563446045
# start G1S
# G1N 9 0.7719221115112305
# start G1
# G2 9 1.1003000736236572
# G1 8 0.7023770809173584
# start G2FS
# G1NS 10 1.5720958709716797
# G1S 9 0.8044240474700928
# start G0
# start G2FNS
# start G2S
# G2N 10 1.6463940143585205
# start G1FS
# G0 7 0.18500423431396484
# start G1FNS
# G1FN 10 1.6751670837402344
# start G2F
# G2FN 11 1.76951003074646
# start G0N
# G2NS 11 1.8157730102539062
# start G1F
# G0N 8 0.356158971786499
# G1F 9 0.552067756652832
# G2S 10 0.9407382011413574
# G2F 10 1.1999411582946777
# G1FS 10 1.7759630680084229
# G2FS 11 2.041897773742676
# G1FNS 11 2.1082160472869873
# G2FNS 12 2.72422194480896
# finished pool
# glycan_dict 20
# start glycan_substructure_dict
# loaded existed substructure_dic
# start merge substructure_dict
# Start merge_glycan_substructure_to_substructure_dict
# combine original
# substructure_dict is merged with len  1856
# finished removing duplicate
# after the cleaning the substructure vec's length is 202
# 1 7
# 2 10
# 3 13
# 4 18
# 5 24
# 6 30
# 7 32
# 8 29
# 9 21
# 10 12
# 11 5
# 12 1
# 202
# finished merge substructure_dic
# 1 7
# 2 10
# 3 13
# 4 18
# 5 24
# 6 30
# 7 32
# 8 29
# 9 21
# 10 12
# 11 5
# 12 1
# 202
# get substructure vec, the length is  202
# start processing G2FN
# start processing G0F
# start processing G1FN
# start processing G2N
# start processing G0FN
# start processing G1N
# start processing G2NS
# start processing G1NS
# start processing G2
# start processing G1S
# start processing G1
# start processing G2FS
# start processing G0
# start processing G2FNS
# start processing G2S
# start processing G1FS
# start processing G1FNS
# start processing G2F
# start processing G0N
# start processing G1F
# closing poll
# joining pool
# finished  1
# finished  3
# finished  8
# finished  5
# finished  4
# finished  0
# finished  2
# finished  9
# finished  10
# finished  11
# finished  12
# finished  7
# finished  6
# finished  14
# finished  15
# finished  18
# finished  17
# finished  19
# finished  13
# finished  16
# converting dict
# finished glycan deconvolution
# the glycan core is
# start substructure_with core
# len 7
# len 8
# len 9
# len 10
# len 11
# len 12
# Finish the n-glycan match  28  substructures are matched to the n-glycan core
# start building dependence_tree
# 7
# 8
# 9
# 10
# 11
# 12
# abd_list 10 profile_list 504
# 10 504
# no external profile naming found
# the glycan core is
# start substructure_with core
# len 7
# len 8
# len 9
# len 10
# len 11
# len 12
# Finish the n-glycan match  28  substructures are matched to the n-glycan core
# start building dependence_tree
# 7
# 8
# 9
# 10
# 11
# 12
# Start dropping nodes with weight zero, nodes count: 28
# Nodes left [5, 14, 25, 40, 65, 84, 89, 93, 112, 115, 116, 120, 123, 140, 143, 144, 146, 147, 150, 166, 168, 169, 171, 172, 185, 186, 188, 196]
# 24 52
# _a.nodes 24
# _a.nodes 24
# merged_weights_dict 24
# After first drop 14 + 10 =  24 24.0
# mod_nodes 10
# mod_edges 15
# _substructure_lab.core_index 108
# 154 G0F False
# 176 G1F False
# 182 G0FN False
# 189 G2F False
# 190 G1FS False
# 195 G1FN False
# 197 G2FS False
# 199 G2FN False
# 200 G1FNS False
# 201 G2FNS False
# Check if the required files exist
# files checked
# Check if the required files exist
# files checked
# Successfully created the directory need, please add the source file is the directory
# Saved /Users/apple/PycharmProjects/GlyCompare/example_data/BE2017/output_data/k_2013_group_1_log_rel_glycan_glycoct_dict.json for future use. You can use "used" in the datatype next time
# start parallel parsing 20 glycans
# start G1FN
# start G2FN
# start G0F
# start G2N
# start G0FN
# start G1N
# start G2NS
# start G1NS
# G0F 8 0.2494831085205078
# start G2
# G2 9 0.8822789192199707
# start G1S
# G0FN 9 1.1223127841949463
# G1N 9 0.5225801467895508
# start G1
# start G2FS
# G1NS 10 2.0233049392700195
# start G0
# G1FN 10 2.096248149871826
# G2N 10 2.1489930152893066
# start G2FNS
# start G2S
# G1 8 0.28997111320495605
# G0 7 0.20416879653930664
# start G1FS
# start G1FNS
# G2FN 11 2.249490976333618
# start G2F
# G2NS 11 2.2716739177703857
# start G0N
# G1S 9 1.3947200775146484
# start G1F
# G0N 8 0.31839513778686523
# G1F 9 0.8931560516357422
# G2S 10 1.260530948638916
# G1FS 10 1.2323329448699951
# G2F 10 1.2681310176849365
# G2FS 11 1.8154618740081787
# G1FNS 11 1.7926299571990967
# G2FNS 12 2.5971310138702393
# finished pool
# glycan_dict 20
# start glycan_substructure_dict
# loaded existed substructure_dic
# start merge substructure_dict
# Start merge_glycan_substructure_to_substructure_dict
# combine original
# substructure_dict is merged with len  1856
# finished removing duplicate
# after the cleaning the substructure vec's length is 202
# 1 7
# 2 10
# 3 13
# 4 18
# 5 24
# 6 30
# 7 32
# 8 29
# 9 21
# 10 12
# 11 5
# 12 1
# 202
# finished merge substructure_dic
# 1 7
# 2 10
# 3 13
# 4 18
# 5 24
# 6 30
# 7 32
# 8 29
# 9 21
# 10 12
# 11 5
# 12 1
# 202
# get substructure vec, the length is  202
# start processing G2FN
# start processing G0F
# start processing G1FN
# start processing G2N
# start processing G0FN
# start processing G1N
# start processing G2NS
# start processing G1NS
# start processing G2
# start processing G1S
# start processing G1
# start processing G2FS
# start processing G0
# start processing G2FNS
# start processing G2S
# start processing G1FS
# start processing G1FNS
# start processing G2F
# start processing G0N
# start processing G1F
# closing poll
# joining pool
# finished  1
# finished  3
# finished  2
# finished  0
# finished  4
# finished  5
# finished  8
# finished  9
# finished  10
# finished  12
# finished  7
# finished  6
# finished  11
# finished  14
# finished  15
# finished  13
# finished  18
# finished  17
# finished  19
# finished  16
# converting dict
# finished glycan deconvolution
# the glycan core is
# start substructure_with core
# len 7
# len 8
# len 9
# len 10
# len 11
# len 12
# Finish the n-glycan match  28  substructures are matched to the n-glycan core
# start building dependence_tree
# 7
# 8
# 9
# 10
# 11
# 12
# abd_list 20 profile_list 669
# 20 669
# no external profile naming found
# the glycan core is
# start substructure_with core
# len 7
# len 8
# len 9
# len 10
# len 11
# len 12
# Finish the n-glycan match  28  substructures are matched to the n-glycan core
# start building dependence_tree
# 7
# 8
# 9
# 10
# 11
# 12
# Start dropping nodes with weight zero, nodes count: 28
# Nodes left []
# 28 60
# _a.nodes 28
# _a.nodes 28
# merged_weights_dict 28
# After first drop 8 + 20 =  28 28.0
# mod_nodes 20
# mod_edges 36
# _substructure_lab.core_index 108
# 108 G0 False
# 139 G1 False
# 148 G0N False
# 154 G0F False
# 164 G2 False
# 165 G1S False
# 173 G1N False
# 176 G1F False
# 182 G0FN False
# 184 G2S False
# 187 G2N False
# 188 G1NS False
# 189 G2F False
# 190 G1FS False
# 195 G1FN False
# 196 G2NS False
# 197 G2FS False
# 199 G2FN False
# 200 G1FNS False
# 201 G2FNS False
# Check if the required files exist
# files checked
# Check if the required files exist
# files checked
# Successfully created the directory need, please add the source file is the directory
# Saved /Users/apple/PycharmProjects/GlyCompare/example_data/BE2017/output_data/k_2013_group_2_log_rel_glycan_glycoct_dict.json for future use. You can use "used" in the datatype next time
# start parallel parsing 20 glycans
# start G0F
# start G2FN
# start G2N
# start G1FN
# start G1N
# start G2NS
# start G0FN
# start G1NS
# G0F 8 0.3900020122528076
# start G2
# G0FN 9 3.130737066268921
# G1N 9 3.1850900650024414
# start G1S
# G2 9 2.846092939376831
# start G1
# start G2FS
# G1NS 10 3.3668859004974365
# G1FN 10 3.365894079208374
# G2N 10 3.3394720554351807
# start G0
# start G2FNS
# start G2S
# G2FN 11 3.53208327293396
# start G1FS
# G0 7 0.16787195205688477
# G2NS 11 3.6395678520202637
# start G1FNS
# start G2F
# G1 8 0.42966318130493164
# start G0N
# G1S 9 0.7186260223388672
# start G1F
# G0N 8 0.45027804374694824
# G1F 9 0.7064597606658936
# G2S 10 1.2730159759521484
# G1FS 10 1.6638171672821045
# G2F 10 1.6346759796142578
# G2FS 11 2.0943410396575928
# G1FNS 11 2.021728038787842
# G2FNS 12 2.834679126739502
# finished pool
# glycan_dict 20
# start glycan_substructure_dict
# loaded existed substructure_dic
# start merge substructure_dict
# Start merge_glycan_substructure_to_substructure_dict
# combine original
# substructure_dict is merged with len  1856
# finished removing duplicate
# after the cleaning the substructure vec's length is 202
# 1 7
# 2 10
# 3 13
# 4 18
# 5 24
# 6 30
# 7 32
# 8 29
# 9 21
# 10 12
# 11 5
# 12 1
# 202
# finished merge substructure_dic
# 1 7
# 2 10
# 3 13
# 4 18
# 5 24
# 6 30
# 7 32
# 8 29
# 9 21
# 10 12
# 11 5
# 12 1
# 202
# get substructure vec, the length is  202
# start processing G2FN
# start processing G0F
# start processing G1FN
# start processing G2N
# start processing G0FN
# start processing G1N
# start processing G2NS
# start processing G1NS
# start processing G2
# start processing G1S
# start processing G1
# start processing G2FS
# start processing G0
# start processing G2FNS
# start processing G2S
# start processing G1FS
# start processing G1FNS
# start processing G2F
# start processing G0N
# start processing G1F
# closing poll
# joining pool
# finished  1
# finished  0
# finished  8
# finished  9
# finished  10
# finished  3
# finished  5
# finished  4
# finished  12
# finished  2
# finished  7
# finished  6
# finished  14
# finished  11
# finished  15
# finished  17
# finished  18
# finished  13
# finished  19
# finished  16
# converting dict
# finished glycan deconvolution
# the glycan core is
# start substructure_with core
# len 7
# len 8
# len 9
# len 10
# len 11
# len 12
# Finish the n-glycan match  28  substructures are matched to the n-glycan core
# start building dependence_tree
# 7
# 8
# 9
# 10
# 11
# 12
# abd_list 20 profile_list 669
# 20 669
# no external profile naming found
# the glycan core is
# start substructure_with core
# len 7
# len 8
# len 9
# len 10
# len 11
# len 12
# Finish the n-glycan match  28  substructures are matched to the n-glycan core
# start building dependence_tree
# 7
# 8
# 9
# 10
# 11
# 12
# Start dropping nodes with weight zero, nodes count: 28
# Nodes left []
# 28 60
# _a.nodes 28
# _a.nodes 28
# merged_weights_dict 28
# After first drop 8 + 20 =  28 28.0
# mod_nodes 20
# mod_edges 36
# _substructure_lab.core_index 108
# 108 G0 False
# 139 G1 False
# 148 G0N False
# 154 G0F False
# 164 G2 False
# 165 G1S False
# 173 G1N False
# 176 G1F False
# 182 G0FN False
# 184 G2S False
# 187 G2N False
# 188 G1NS False
# 189 G2F False
# 190 G1FS False
# 195 G1FN False
# 196 G2NS False
# 197 G2FS False
# 199 G2FN False
# 200 G1FNS False
# 201 G2FNS False
# Check if the required files exist
# files checked
# Check if the required files exist
# files checked
# Successfully created the directory need, please add the source file is the directory
# Saved /Users/apple/PycharmProjects/GlyCompare/example_data/BE2017/output_data/k_2013_group_4_log_rel_glycan_glycoct_dict.json for future use. You can use "used" in the datatype next time
# start parallel parsing 20 glycans
# start G2FN
# start G0F
# start G2N
# start G1FN
# start G0FN
# start G2NS
# start G1N
# start G1NS
# G0F 8 0.36107516288757324
# start G2
# G0FN 9 0.7946228981018066
# start G1S
# G1N 9 0.8442308902740479
# start G1
# G2 9 0.7266550064086914
# start G2FS
# G1 8 0.3585469722747803
# start G0
# G2N 10 1.3716340065002441
# start G2FNS
# G1FN 10 1.4456048011779785
# G0 7 0.9489181041717529
# start G2S
# G1NS 10 2.3245272636413574
# G1S 9 1.5168719291687012
# start G1FS
# start G1FNS
# start G2F
# G2NS 11 2.478658676147461
# start G0N
# G2FN 11 2.626361131668091
# start G1F
# G2FS 11 1.5717079639434814
# G0N 8 0.43860793113708496
# G1F 9 0.5976388454437256
# G2S 10 1.171051025390625
# G1FS 10 1.1500909328460693
# G2F 10 1.1182770729064941
# G1FNS 11 1.6154859066009521
# G2FNS 12 2.654836893081665
# finished pool
# glycan_dict 20
# start glycan_substructure_dict
# loaded existed substructure_dic
# start merge substructure_dict
# Start merge_glycan_substructure_to_substructure_dict
# combine original
# substructure_dict is merged with len  1856
# finished removing duplicate
# after the cleaning the substructure vec's length is 202
# 1 7
# 2 10
# 3 13
# 4 18
# 5 24
# 6 30
# 7 32
# 8 29
# 9 21
# 10 12
# 11 5
# 12 1
# 202
# finished merge substructure_dic
# 1 7
# 2 10
# 3 13
# 4 18
# 5 24
# 6 30
# 7 32
# 8 29
# 9 21
# 10 12
# 11 5
# 12 1
# 202
# get substructure vec, the length is  202
# start processing G2FN
# start processing G0F
# start processing G1FN
# start processing G2N
# start processing G0FN
# start processing G1N
# start processing G2NS
# start processing G1NS
# start processing G2
# start processing G1S
# start processing G1
# start processing G2FS
# start processing G0
# start processing G2FNS
# start processing G2S
# start processing G1FS
# start processing G1FNS
# start processing G2F
# start processing G0N
# start processing G1F
# closing poll
# joining pool
# finished  1
# finished  3
# finished  5
# finished  4
# finished  8
# finished  0
# finished  2
# finished  10
# finished  9
# finished  6
# finished  7
# finished  12
# finished  11
# finished  14
# finished  18
# finished  17
# finished  13
# finished  15
# finished  19
# finished  16
# converting dict
# finished glycan deconvolution
# the glycan core is
# start substructure_with core
# len 7
# len 8
# len 9
# len 10
# len 11
# len 12
# Finish the n-glycan match  28  substructures are matched to the n-glycan core
# start building dependence_tree
# 7
# 8
# 9
# 10
# 11
# 12
# abd_list 10 profile_list 669
# 10 669
# no external profile naming found
# the glycan core is
# start substructure_with core
# len 7
# len 8
# len 9
# len 10
# len 11
# len 12
# Finish the n-glycan match  28  substructures are matched to the n-glycan core
# start building dependence_tree
# 7
# 8
# 9
# 10
# 11
# 12
# Start dropping nodes with weight zero, nodes count: 28
# Nodes left [5, 14, 25, 40, 65, 84, 89, 93, 112, 115, 116, 120, 123, 140, 143, 144, 146, 147, 150, 166, 168, 169, 171, 172, 185, 186, 188, 196]
# 24 52
# _a.nodes 24
# _a.nodes 24
# merged_weights_dict 24
# After first drop 14 + 10 =  24 24.0
# mod_nodes 10
# mod_edges 15
# _substructure_lab.core_index 108
# 154 G0F False
# 176 G1F False
# 182 G0FN False
# 189 G2F False
# 190 G1FS False
# 195 G1FN False
# 197 G2FS False
# 199 G2FN False
# 200 G1FNS False
# 201 G2FNS False
# Check if the required files exist
# files checked
# Check if the required files exist
# files checked
# Successfully created the directory need, please add the source file is the directory
# Saved /Users/apple/PycharmProjects/GlyCompare/example_data/BE2017/output_data/split_group_1_log_rel_glycan_glycoct_dict.json for future use. You can use "used" in the datatype next time
# start parallel parsing 20 glycans
# start G0FN
# start G0F
# start G2N
# start G1N
# start G1FN
# start G2FN
# start G2NS
# start G1NS
# G0F 8 0.4129447937011719
# start G2
# G2 9 1.3727858066558838
# start G1S
# G1N 9 0.8800661563873291
# start G1
# G1 8 0.41283607482910156
# start G2FS
# G0FN 9 1.8516991138458252
# G1NS 10 1.9350941181182861
# start G0
# G2N 10 3.320535898208618
# start G2FNS
# start G2S
# G1FN 10 3.4051389694213867
# start G1FS
# G0 7 0.22195887565612793
# G2FN 11 3.571561813354492
# start G1FNS
# start G2F
# G2NS 11 3.7142951488494873
# start G0N
# G1S 9 2.159067153930664
# start G1F
# G0N 8 0.5756378173828125
# G2FS 11 2.3869152069091797
# G2S 10 1.393036127090454
# G1F 9 0.7770118713378906
# G1FS 10 1.3572380542755127
# G2F 10 1.2092769145965576
# G1FNS 11 2.112362861633301
# G2FNS 12 2.6129701137542725
# finished pool
# glycan_dict 20
# start glycan_substructure_dict
# loaded existed substructure_dic
# start merge substructure_dict
# Start merge_glycan_substructure_to_substructure_dict
# combine original
# substructure_dict is merged with len  1856
# finished removing duplicate
# after the cleaning the substructure vec's length is 202
# 1 7
# 2 10
# 3 13
# 4 18
# 5 24
# 6 30
# 7 32
# 8 29
# 9 21
# 10 12
# 11 5
# 12 1
# 202
# finished merge substructure_dic
# 1 7
# 2 10
# 3 13
# 4 18
# 5 24
# 6 30
# 7 32
# 8 29
# 9 21
# 10 12
# 11 5
# 12 1
# 202
# get substructure vec, the length is  202
# start processing G2FN
# start processing G0F
# start processing G1FN
# start processing G2N
# start processing G0FN
# start processing G1N
# start processing G2NS
# start processing G1NS
# start processing G2
# start processing G1S
# start processing G1
# start processing G2FS
# start processing G0
# start processing G2FNS
# start processing G2S
# start processing G1FS
# start processing G1FNS
# start processing G2F
# start processing G0N
# start processing G1F
# closing poll
# joining pool
# finished  1
# finished  3
# finished  0
# finished  5
# finished  4
# finished  2
# finished  6
# finished  8
# finished  9
# finished  12
# finished  7
# finished  11
# finished  14
# finished  10
# finished  18
# finished  15
# finished  17
# finished  19
# finished  13
# finished  16
# converting dict
# finished glycan deconvolution
# the glycan core is
# start substructure_with core
# len 7
# len 8
# len 9
# len 10
# len 11
# len 12
# Finish the n-glycan match  28  substructures are matched to the n-glycan core
# start building dependence_tree
# 7
# 8
# 9
# 10
# 11
# 12
# abd_list 20 profile_list 980
# 20 980
# no external profile naming found
# the glycan core is
# start substructure_with core
# len 7
# len 8
# len 9
# len 10
# len 11
# len 12
# Finish the n-glycan match  28  substructures are matched to the n-glycan core
# start building dependence_tree
# 7
# 8
# 9
# 10
# 11
# 12
# Start dropping nodes with weight zero, nodes count: 28
# Nodes left []
# 28 60
# _a.nodes 28
# _a.nodes 28
# merged_weights_dict 28
# After first drop 8 + 20 =  28 28.0
# mod_nodes 20
# mod_edges 36
# _substructure_lab.core_index 108
# 108 G0 False
# 139 G1 False
# 148 G0N False
# 154 G0F False
# 164 G2 False
# 165 G1S False
# 173 G1N False
# 176 G1F False
# 182 G0FN False
# 184 G2S False
# 187 G2N False
# 188 G1NS False
# 189 G2F False
# 190 G1FS False
# 195 G1FN False
# 196 G2NS False
# 197 G2FS False
# 199 G2FN False
# 200 G1FNS False
# 201 G2FNS False
# Check if the required files exist
# files checked
# Check if the required files exist
# files checked
# Successfully created the directory need, please add the source file is the directory
# Saved /Users/apple/PycharmProjects/GlyCompare/example_data/BE2017/output_data/split_group_2_log_rel_glycan_glycoct_dict.json for future use. You can use "used" in the datatype next time
# start parallel parsing 20 glycans
# start G2FN
# start G0F
# start G1FN
# start G0FN
# start G2N
# start G1N
# start G2NS
# start G1NS
# G0F 8 0.2585921287536621
# start G2
# G1N 9 0.46903276443481445
# start G1S
# G0FN 9 0.5178601741790771
# start G1
# G2 9 0.3971278667449951
# start G2FS
# G1 8 0.3100152015686035
# G2N 10 0.8527810573577881
# G1FN 10 0.9459950923919678
# start G0
# start G2FNS
# start G2S
# G1NS 10 0.98435378074646
# start G1FS
# G1S 9 0.532771110534668
# start G1FNS
# G0 7 0.15738201141357422
# start G2F
# G2FN 11 1.5706229209899902
# start G0N
# G2NS 11 2.3724091053009033
# G2S 10 1.4136672019958496
# G1FS 10 1.3915379047393799
# start G1F
# G2F 10 1.3282690048217773
# G2FS 11 1.8732869625091553
# G0N 8 0.27831578254699707
# G1FNS 11 1.6655521392822266
# G1F 9 0.33571290969848633
# G2FNS 12 2.320668935775757
# finished pool
# glycan_dict 20
# start glycan_substructure_dict
# loaded existed substructure_dic
# start merge substructure_dict
# Start merge_glycan_substructure_to_substructure_dict
# combine original
# substructure_dict is merged with len  1856
# finished removing duplicate
# after the cleaning the substructure vec's length is 202
# 1 7
# 2 10
# 3 13
# 4 18
# 5 24
# 6 30
# 7 32
# 8 29
# 9 21
# 10 12
# 11 5
# 12 1
# 202
# finished merge substructure_dic
# 1 7
# 2 10
# 3 13
# 4 18
# 5 24
# 6 30
# 7 32
# 8 29
# 9 21
# 10 12
# 11 5
# 12 1
# 202
# get substructure vec, the length is  202
# start processing G2FN
# start processing G0F
# start processing G1FN
# start processing G2N
# start processing G0FN
# start processing G1N
# start processing G2NS
# start processing G1NS
# start processing G2
# start processing G1S
# start processing G1
# start processing G2FS
# start processing G0
# start processing G2FNS
# start processing G2S
# start processing G1FS
# start processing G1FNS
# start processing G2F
# start processing G0N
# start processing G1F
# closing poll
# joining pool
# finished  1
# finished  3
# finished  2
# finished  5
# finished  4
# finished  0
# finished  7
# finished  6
# finished  8
# finished  9
# finished  10
# finished  12
# finished  18
# finished  17
# finished  11
# finished  14
# finished  19
# finished  13
# finished  15
# finished  16
# converting dict
# finished glycan deconvolution
# the glycan core is
# start substructure_with core
# len 7
# len 8
# len 9
# len 10
# len 11
# len 12
# Finish the n-glycan match  28  substructures are matched to the n-glycan core
# start building dependence_tree
# 7
# 8
# 9
# 10
# 11
# 12
# abd_list 20 profile_list 980
# 20 980
# no external profile naming found
# the glycan core is
# start substructure_with core
# len 7
# len 8
# len 9
# len 10
# len 11
# len 12
# Finish the n-glycan match  28  substructures are matched to the n-glycan core
# start building dependence_tree
# 7
# 8
# 9
# 10
# 11
# 12
# Start dropping nodes with weight zero, nodes count: 28
# Nodes left []
# 28 60
# _a.nodes 28
# _a.nodes 28
# merged_weights_dict 28
# After first drop 8 + 20 =  28 28.0
# mod_nodes 20
# mod_edges 36
# _substructure_lab.core_index 108
# 108 G0 False
# 139 G1 False
# 148 G0N False
# 154 G0F False
# 164 G2 False
# 165 G1S False
# 173 G1N False
# 176 G1F False
# 182 G0FN False
# 184 G2S False
# 187 G2N False
# 188 G1NS False
# 189 G2F False
# 190 G1FS False
# 195 G1FN False
# 196 G2NS False
# 197 G2FS False
# 199 G2FN False
# 200 G1FNS False
# 201 G2FNS False
# Check if the required files exist
# files checked
# Check if the required files exist
# files checked
# Successfully created the directory need, please add the source file is the directory
# Saved /Users/apple/PycharmProjects/GlyCompare/example_data/BE2017/output_data/split_group_4_log_rel_glycan_glycoct_dict.json for future use. You can use "used" in the datatype next time
# start parallel parsing 20 glycans
# start G0F
# start G2FN
# start G1FN
# start G0FN
# start G2N
# start G1N
# start G2NS
# start G1NS
# G0F 8 0.2487502098083496
# start G2
# G0FN 9 0.4945530891418457
# start G1S
# G1N 9 0.5493969917297363
# start G1
# G2 9 0.44313716888427734
# start G2FS
# G1 8 0.2803769111633301
# G2N 10 0.8828620910644531
# start G0
# start G2FNS
# G1FN 10 0.9691257476806641
# start G2S
# G0 7 0.1206059455871582
# G1NS 10 1.0173099040985107
# start G1FS
# start G1FNS
# G1S 9 0.5394749641418457
# start G2F
# G2FN 11 1.598526954650879
# start G0N
# G2NS 11 2.3934988975524902
# start G1F
# G2S 10 1.3963580131530762
# G2F 10 1.3337647914886475
# G1FS 10 1.4170639514923096
# G2FS 11 1.8464360237121582
# G1FNS 11 1.5526649951934814
# G0N 8 0.3398110866546631
# G1F 9 0.3787980079650879
# G2FNS 12 2.2076852321624756
# finished pool
# glycan_dict 20
# start glycan_substructure_dict
# loaded existed substructure_dic
# start merge substructure_dict
# Start merge_glycan_substructure_to_substructure_dict
# combine original
# substructure_dict is merged with len  1856
# finished removing duplicate
# after the cleaning the substructure vec's length is 202
# 1 7
# 2 10
# 3 13
# 4 18
# 5 24
# 6 30
# 7 32
# 8 29
# 9 21
# 10 12
# 11 5
# 12 1
# 202
# finished merge substructure_dic
# 1 7
# 2 10
# 3 13
# 4 18
# 5 24
# 6 30
# 7 32
# 8 29
# 9 21
# 10 12
# 11 5
# 12 1
# 202
# get substructure vec, the length is  202
# start processing G2FN
# start processing G0F
# start processing G1FN
# start processing G2N
# start processing G0FN
# start processing G1N
# start processing G2NS
# start processing G1NS
# start processing G2
# start processing G1S
# start processing G1
# start processing G2FS
# start processing G0
# start processing G2FNS
# start processing G2S
# start processing G1FS
# start processing G1FNS
# start processing G2F
# start processing G0N
# start processing G1F
# closing poll
# joining pool
# finished  1
# finished  0
# finished  2
# finished  9
# finished  10
# finished  12
# finished  3
# finished  5
# finished  8
# finished  4
# finished  11
# finished  14
# finished  7
# finished  6
# finished  15
# finished  18
# finished  17
# finished  19
# finished  16
# finished  13
# converting dict
# finished glycan deconvolution
# the glycan core is
# start substructure_with core
# len 7
# len 8
# len 9
# len 10
# len 11
# len 12
# Finish the n-glycan match  28  substructures are matched to the n-glycan core
# start building dependence_tree
# 7
# 8
# 9
# 10
# 11
# 12
# abd_list 10 profile_list 980
# 10 980
# no external profile naming found
# the glycan core is
# start substructure_with core
# len 7
# len 8
# len 9
# len 10
# len 11
# len 12
# Finish the n-glycan match  28  substructures are matched to the n-glycan core
# start building dependence_tree
# 7
# 8
# 9
# 10
# 11
# 12
# Start dropping nodes with weight zero, nodes count: 28
# Nodes left [5, 14, 25, 40, 65, 84, 89, 93, 112, 115, 116, 120, 123, 140, 143, 144, 146, 147, 150, 166, 168, 169, 171, 172, 185, 186, 188, 196]
# 24 52
# _a.nodes 24
# _a.nodes 24
# merged_weights_dict 24
# After first drop 14 + 10 =  24 24.0
# mod_nodes 10
# mod_edges 15
# _substructure_lab.core_index 108
# 154 G0F False
# 176 G1F False
# 182 G0FN False
# 189 G2F False
# 190 G1FS False
# 195 G1FN False
# 197 G2FS False
# 199 G2FN False
# 200 G1FNS False
# 201 G2FNS False
# Check if the required files exist
# files checked
# Check if the required files exist
# files checked
# Successfully created the directory need, please add the source file is the directory
# Saved /Users/apple/PycharmProjects/GlyCompare/example_data/BE2017/output_data/vis_group_1_log_rel_glycan_glycoct_dict.json for future use. You can use "used" in the datatype next time
# start parallel parsing 20 glycans
# start G2FN
# start G0F
# start G1FN
# start G0FN
# start G2N
# start G1NS
# start G1N
# start G2NS
# G0F 8 0.27320289611816406
# start G2
# G1N 9 0.5504968166351318
# start G1S
# G0FN 9 0.6074202060699463
# start G1
# G2 9 0.4718129634857178
# start G2FS
# G1 8 0.2454061508178711
# start G0
# G2N 10 1.0013036727905273
# start G2FNS
# G1NS 10 1.0710747241973877
# G0 7 0.20154714584350586
# G1FN 10 1.1206450462341309
# start G2S
# start G1FS
# G1S 9 0.5436978340148926
# start G1FNS
# start G2F
# G2FN 11 1.662517786026001
# start G0N
# G2NS 11 1.770380973815918
# start G1F
# G2S 10 0.9658002853393555
# G0N 8 1.0311448574066162
# G2F 10 1.6415181159973145
# G1FS 10 1.7085480690002441
# G1F 9 1.0489537715911865
# G2FS 11 2.1634490489959717
# G1FNS 11 1.8398401737213135
# G2FNS 12 2.230246067047119
# finished pool
# glycan_dict 20
# start glycan_substructure_dict
# loaded existed substructure_dic
# start merge substructure_dict
# Start merge_glycan_substructure_to_substructure_dict
# combine original
# substructure_dict is merged with len  1856
# finished removing duplicate
# after the cleaning the substructure vec's length is 202
# 1 7
# 2 10
# 3 13
# 4 18
# 5 24
# 6 30
# 7 32
# 8 29
# 9 21
# 10 12
# 11 5
# 12 1
# 202
# finished merge substructure_dic
# 1 7
# 2 10
# 3 13
# 4 18
# 5 24
# 6 30
# 7 32
# 8 29
# 9 21
# 10 12
# 11 5
# 12 1
# 202
# get substructure vec, the length is  202
# start processing G2FN
# start processing G0F
# start processing G1FN
# start processing G2N
# start processing G0FN
# start processing G1N
# start processing G2NS
# start processing G1NS
# start processing G2
# start processing G1S
# start processing G1
# start processing G2FS
# start processing G0
# start processing G2FNS
# start processing G2S
# start processing G1FS
# start processing G1FNS
# start processing G2F
# start processing G0N
# start processing G1F
# closing poll
# joining pool
# finished  1
# finished  3
# finished  0
# finished  5
# finished  2
# finished  4
# finished  8
# finished  6
# finished  7
# finished  9
# finished  10
# finished  12
# finished  11
# finished  15
# finished  14
# finished  16
# finished  17
# finished  18
# finished  19
# finished  13
# converting dict
# finished glycan deconvolution
# the glycan core is
# start substructure_with core
# len 7
# len 8
# len 9
# len 10
# len 11
# len 12
# Finish the n-glycan match  28  substructures are matched to the n-glycan core
# start building dependence_tree
# 7
# 8
# 9
# 10
# 11
# 12
# abd_list 20 profile_list 395
# 20 395
# no external profile naming found
# the glycan core is
# start substructure_with core
# len 7
# len 8
# len 9
# len 10
# len 11
# len 12
# Finish the n-glycan match  28  substructures are matched to the n-glycan core
# start building dependence_tree
# 7
# 8
# 9
# 10
# 11
# 12
# Start dropping nodes with weight zero, nodes count: 28
# Nodes left []
# 28 60
# _a.nodes 28
# _a.nodes 28
# merged_weights_dict 28
# After first drop 8 + 20 =  28 28.0
# mod_nodes 20
# mod_edges 36
# _substructure_lab.core_index 108
# 108 G0 False
# 139 G1 False
# 148 G0N False
# 154 G0F False
# 164 G2 False
# 165 G1S False
# 173 G1N False
# 176 G1F False
# 182 G0FN False
# 184 G2S False
# 187 G2N False
# 188 G1NS False
# 189 G2F False
# 190 G1FS False
# 195 G1FN False
# 196 G2NS False
# 197 G2FS False
# 199 G2FN False
# 200 G1FNS False
# 201 G2FNS False
# Check if the required files exist
# files checked
# Check if the required files exist
# files checked
# Successfully created the directory need, please add the source file is the directory
# Saved /Users/apple/PycharmProjects/GlyCompare/example_data/BE2017/output_data/vis_group_2_log_rel_glycan_glycoct_dict.json for future use. You can use "used" in the datatype next time
# start parallel parsing 20 glycans
# start G2FN
# start G0F
# start G1FN
# start G0FN
# start G2N
# start G1N
# start G2NS
# start G1NS
# G0F 8 0.261707067489624
# start G2
# G2 9 1.332442045211792
# start G1S
# G1FN 10 1.9473779201507568
# G2N 10 2.0236380100250244
# start G1
# start G2FS
# G1NS 10 2.089085817337036
# start G0
# G0 7 0.15209293365478516
# start G2FNS
# G1 8 0.2914011478424072
# start G2S
# G1N 9 0.5126960277557373
# G2FN 11 2.7965240478515625
# start G1FS
# start G1FNS
# G0FN 9 1.575650930404663
# start G2F
# G2NS 11 2.9256937503814697
# start G0N
# G0N 8 0.39019203186035156
# start G1F
# G2S 10 1.2814910411834717
# G1S 9 2.1159729957580566
# G1F 9 0.6088039875030518
# G2FS 11 2.033784866333008
# G1FS 10 1.236402988433838
# G2F 10 1.2439947128295898
# G1FNS 11 1.7536311149597168
# G2FNS 12 3.1992969512939453
# finished pool
# glycan_dict 20
# start glycan_substructure_dict
# loaded existed substructure_dic
# start merge substructure_dict
# Start merge_glycan_substructure_to_substructure_dict
# combine original
# substructure_dict is merged with len  1856
# finished removing duplicate
# after the cleaning the substructure vec's length is 202
# 1 7
# 2 10
# 3 13
# 4 18
# 5 24
# 6 30
# 7 32
# 8 29
# 9 21
# 10 12
# 11 5
# 12 1
# 202
# finished merge substructure_dic
# 1 7
# 2 10
# 3 13
# 4 18
# 5 24
# 6 30
# 7 32
# 8 29
# 9 21
# 10 12
# 11 5
# 12 1
# 202
# get substructure vec, the length is  202
# start processing G2FN
# start processing G0F
# start processing G1FN
# start processing G2N
# start processing G0FN
# start processing G1N
# start processing G2NS
# start processing G1NS
# start processing G2
# start processing G1S
# start processing G1
# start processing G2FS
# start processing G0
# start processing G2FNS
# start processing G2S
# start processing G1FS
# start processing G1FNS
# start processing G2F
# start processing G0N
# start processing G1F
# closing poll
# joining pool
# finished  1
# finished  3
# finished  5
# finished  0
# finished  8
# finished  2
# finished  4
# finished  9
# finished  10
# finished  7
# finished  6
# finished  12
# finished  11
# finished  14
# finished  13
# finished  15
# finished  18
# finished  17
# finished  19
# finished  16
# converting dict
# finished glycan deconvolution
# the glycan core is
# start substructure_with core
# len 7
# len 8
# len 9
# len 10
# len 11
# len 12
# Finish the n-glycan match  28  substructures are matched to the n-glycan core
# start building dependence_tree
# 7
# 8
# 9
# 10
# 11
# 12
# abd_list 20 profile_list 395
# 20 395
# no external profile naming found
# the glycan core is
# start substructure_with core
# len 7
# len 8
# len 9
# len 10
# len 11
# len 12
# Finish the n-glycan match  28  substructures are matched to the n-glycan core
# start building dependence_tree
# 7
# 8
# 9
# 10
# 11
# 12
# Start dropping nodes with weight zero, nodes count: 28
# Nodes left []
# 28 60
# _a.nodes 28
# _a.nodes 28
# merged_weights_dict 28
# After first drop 8 + 20 =  28 28.0
# mod_nodes 20
# mod_edges 36
# _substructure_lab.core_index 108
# 108 G0 False
# 139 G1 False
# 148 G0N False
# 154 G0F False
# 164 G2 False
# 165 G1S False
# 173 G1N False
# 176 G1F False
# 182 G0FN False
# 184 G2S False
# 187 G2N False
# 188 G1NS False
# 189 G2F False
# 190 G1FS False
# 195 G1FN False
# 196 G2NS False
# 197 G2FS False
# 199 G2FN False
# 200 G1FNS False
# 201 G2FNS False
# Check if the required files exist
# files checked
# Check if the required files exist
# files checked
# Successfully created the directory need, please add the source file is the directory
# Saved /Users/apple/PycharmProjects/GlyCompare/example_data/BE2017/output_data/vis_group_4_log_rel_glycan_glycoct_dict.json for future use. You can use "used" in the datatype next time
# start parallel parsing 20 glycans
# start G2FN
# start G0F
# start G2N
# start G1FN
# start G0FN
# start G2NS
# start G1N
# start G1NS
# G0F 8 0.297274112701416
# start G2
# G0FN 9 0.5661706924438477
# start G1S
# G1N 9 0.6073558330535889
# start G1
# G2 9 0.4876821041107178
# start G2FS
# G1 8 0.25689220428466797
# start G0
# G2N 10 1.0351128578186035
# G1FN 10 1.1105139255523682
# G0 7 0.19739603996276855
# start G2FNS
# start G2S
# start G1FS
# G1NS 10 1.162024974822998
# start G1FNS
# G1S 9 0.6037998199462891
# start G2F
# G2FN 11 2.9435348510742188
# G1FS 10 1.79960298538208
# G2NS 11 3.0349490642547607
# start G0N
# G2F 10 1.7963249683380127
# G2S 10 1.9289050102233887
# start G1F
# G2FS 11 2.34916615486145
# G1FNS 11 2.0259392261505127
# G0N 8 0.2998051643371582
# G1F 9 0.43546295166015625
# G2FNS 12 2.6184961795806885
# finished pool
# glycan_dict 20
# start glycan_substructure_dict
# loaded existed substructure_dic
# start merge substructure_dict
# Start merge_glycan_substructure_to_substructure_dict
# combine original
# substructure_dict is merged with len  1856
# finished removing duplicate
# after the cleaning the substructure vec's length is 202
# 1 7
# 2 10
# 3 13
# 4 18
# 5 24
# 6 30
# 7 32
# 8 29
# 9 21
# 10 12
# 11 5
# 12 1
# 202
# finished merge substructure_dic
# 1 7
# 2 10
# 3 13
# 4 18
# 5 24
# 6 30
# 7 32
# 8 29
# 9 21
# 10 12
# 11 5
# 12 1
# 202
# get substructure vec, the length is  202
# start processing G2FN
# start processing G0F
# start processing G1FN
# start processing G2N
# start processing G0FN
# start processing G1N
# start processing G2NS
# start processing G1NS
# start processing G2
# start processing G1S
# start processing G1
# start processing G2FS
# start processing G0
# start processing G2FNS
# start processing G2S
# start processing G1FS
# start processing G1FNS
# start processing G2F
# start processing G0N
# start processing G1F
# closing poll
# joining pool
# finished  1
# finished  3
# finished  5
# finished  0
# finished  2
# finished  4
# finished  6
# finished  8
# finished  9
# finished  10
# finished  7
# finished  12
# finished  14
# finished  18
# finished  11
# finished  15
# finished  17
# finished  19
# finished  13
# finished  16
# converting dict
# finished glycan deconvolution
# the glycan core is
# start substructure_with core
# len 7
# len 8
# len 9
# len 10
# len 11
# len 12
# Finish the n-glycan match  28  substructures are matched to the n-glycan core
# start building dependence_tree
# 7
# 8
# 9
# 10
# 11
# 12
# abd_list 10 profile_list 395
# 10 395
# no external profile naming found
# the glycan core is
# start substructure_with core
# len 7
# len 8
# len 9
# len 10
# len 11
# len 12
# Finish the n-glycan match  28  substructures are matched to the n-glycan core
# start building dependence_tree
# 7
# 8
# 9
# 10
# 11
# 12
# Start dropping nodes with weight zero, nodes count: 28
# Nodes left [5, 14, 25, 40, 65, 84, 89, 93, 112, 115, 116, 120, 123, 140, 143, 144, 146, 147, 150, 166, 168, 169, 171, 172, 185, 186, 188, 196]
# 24 52
# _a.nodes 24
# _a.nodes 24
# merged_weights_dict 24
# After first drop 14 + 10 =  24 24.0
# mod_nodes 10
# mod_edges 15
# _substructure_lab.core_index 108
# 154 G0F False
# 176 G1F False
# 182 G0FN False
# 189 G2F False
# 190 G1FS False
# 195 G1FN False
# 197 G2FS False
# 199 G2FN False
# 200 G1FNS False
# 201 G2FNS False

# %%
# reload(pipeline_functions)
# core = substructure_dict[108]
# substructure_glycoct_dict_addr = keywords_dict['substructure_glycoct_dict_addr']
# # assert os.path.isfile(substructure_glycoct_dict_addr), 'missing ' + substructure_glycoct_dict_addr
# substructure_abd_table_addr = keywords_dict['substructure_abd_table_addr']
# substructure_abd_table = pd.read_csv(substructure_abd_table_addr, index_col=0)
# substructure_dict = glycan_io.load_substructure_vec_from_json(substructure_glycoct_dict_addr)
# # _substructure_lab = select_substructures.substructureLabwithCore(substructure_dict, glycan_core=select_substructures.nglycan_core, linkage_specific=False)  # unicarbkb_substructures_12259.json
# # _substructure_lab.get_dependence_tree_core()

# # if not select_col:
# select_col = substructure_abd_table.columns
# _substructure_lab = select_motifs.substructureLabwithCore(substructure_=substructure_dict,
#                                                     glycan_core=core,
#                                                     linkage_specific=linkage_specific)  # unicarbkb_substructures_12259.json
# _substructure_lab.get_dependence_tree_core()
# a_node_state = select_motifs.NodesState(dependence_tree=_substructure_lab.substructure_dep_tree_core,
#                                                 substructure_weight=select_motifs.get_weight_dict(
#                                                     substructure_abd_table[select_col]),
#                                                 linkage_specific=linkage_specific)
# node_attri, edge_attri, mod_nodes, mod_edges, merged_weights_dict = a_node_state.nodes_dropping_pipe(
# drop_parellel=False, drop_diff_abund=False)
# print('_substructure_lab.core_index',_substructure_lab.core_index)
# # if _substructure_lab.core_index in mod_nodes:
# #         mod_nodes.remove(_substructure_lab.core_index)
# #         print("Removed core, the index is", _substructure_lab.core_index)
# motif_dict = {}
# for i in mod_nodes:
#     motif_dict[i] = _substructure_lab.substructure_vec[i]
# glycan_io.output_glycan_dict_to_glycoct_dict(motif_dict, keywords_dict['motif_glycoct_dict_addr'])

# motif_abd_table = substructure_abd_table[select_col][substructure_abd_table.index.isin(mod_nodes)]
# motif_abd_table_addr = keywords_dict['motif_abd_table_addr']
# motif_abd_table.to_csv(motif_abd_table_addr)
# for i in mod_nodes:
#     plot_glycan_utilities.plot_glycan(_substructure_lab.substructure_vec[i], 
#                                       title=i, 
#                                       label=True,
#                                       addr=keywords_dict['plot_output_dir'] + 'motif_'+str(i)+'.eps')
# #     plt.savefig()
# #     print(keywords_dict['plot_output_dir'] + 'motif_'+str(i)+'.eps')
# Out:
# the glycan core is
# start substructure_with core
# len 7
# len 8
# len 9
# len 10
# len 11
# len 12
# Finish the n-glycan match  28  substructures are matched to the n-glycan core
# start building dependence_tree
# 7
# 8
# 9
# 10
# 11
# 12
# Start dropping nodes with weight zero, nodes count: 28
# Nodes left []
# 28 60
# _a.nodes 28
# _a.nodes 28
# merged_weights_dict 28
# After first drop 8 + 20 =  28 28.0
# mod_nodes 20
# mod_edges 36
# _substructure_lab.core_index 108

# %%
index_list = sorted(list(node_attri.keys()))
keep_list = [node_attri[i]['kept'] for i in index_list]
from glypy.algorithms.subtree_search.inclusion import subtree_of

motif_glycan_mapping = []
for i in index_list:
    if i in mod_nodes: 
        found=False
        for j in glycan_dict:
            if subtree_of(_substructure_lab.substructure_vec[i], glycan_dict[j], exact=True) ==1 \
                and subtree_of(glycan_dict[j], _substructure_lab.substructure_vec[i],  exact=True) ==1:
                print(i,j, found)
                found=True
                break
        if found:
            motif_glycan_mapping.append(j)
        else:
            motif_glycan_mapping.apend('N')
        
    else:
        motif_glycan_mapping.append('N')
# motif_glycan_mapping
pd.DataFrame(data={'index':index_list, 'keep':keep_list, 'if_glycan':motif_glycan_mapping}).to_csv('/Users/apple/PycharmProjects/GlyCompare/example_data/BE2017/output_data/node_list.csv')
# Out:
# 139 G1 False
# 148 G0N False
# 154 G0F False
# 164 G2 False
# 165 G1S False
# 173 G1N False
# 176 G1F False
# 182 G0FN False
# 184 G2S False
# 187 G2N False
# 188 G1NS False
# 189 G2F False
# 190 G1FS False
# 195 G1FN False
# 196 G2NS False
# 197 G2FS False
# 199 G2FN False
# 200 G1FNS False
# 201 G2FNS False

# %%
def _parse_edge_attri_to_table(edge_dict):
#     edge_start=[]
#     edge_end = []
    edge_attri_dict = {'start':[], 'end':[]}
    _attributes_checked = False
    for _nodes in edge_dict:
        for _sub_nodes in edge_dict[_nodes]:
            if not _attributes_checked:
                for _key in edge_dict[_nodes][_sub_nodes]:
                    edge_attri_dict[_key] = []
                _attributes_checked=True
            for _key in edge_dict[_nodes][_sub_nodes]:
#                 print(_nodes, _sub_nodes, edge_dict[_nodes][_sub_nodes][_key])
                edge_attri_dict[_key].append(edge_dict[_nodes][_sub_nodes][_key])
            edge_attri_dict['start'].append(_nodes)
            edge_attri_dict['end'].append(_sub_nodes)
    return edge_attri_dict
pd.DataFrame(_parse_edge_attri_to_table(edge_attri)).to_csv('/Users/apple/PycharmProjects/GlyCompare/example_data/BE2017/output_data/edge_list.csv')

# %%
# keywords_dict['abundance_table.csv'] = 
# glycoprofile_cluster_dict, glyco_motif_cluster_dict = pipeline_functions.clustering_analysis_pip(keywords_dict=keywords_dict, 
#                                            motif_abd_table=motif_abd_table, )
# glycoprofile_cluster_dict, glyco_motif_cluster_dict = pipeline_functions.clustering_analysis_pip(keywords_dict=keywords_dict, 
#                                            motif_abd_table=motif_abd_table, 
#                                            select_profile_name = selected_name_list)
selected_name_list = motif_abd_table.columns.tolist()

    # df_ncore=pd.DataFrame(data=preprocessing.scale(df_ncore.transpose()).transpose(), index=df_ncore.index, columns=df_ncore.columns)
    # motif_abd_table.to_csv(os.path.join(keywords_dict['intermediate_dir'],
    #                                     str(len(selected_name_list)) + r"selected_abundance_matrix.txt"))
    # motif_abd_table.colmuns = selected_name_list

    # plt.savefig(keywords_dict['plot_output_dir'] + 'pseudo_profile_clustering.svg')
# motif_abd_table.drop()
cluster_grid = clustering_analysis.draw_glycan_clustermap(motif_abd_table=motif_abd_table,
                                                              address=keywords_dict[
                                                                          'plot_output_dir'] + 'pseudo_profile_clustering.eps',
                                                              metric="correlation",
                                                              cmap=sns.cubehelix_palette(8, start=.5, rot=-.75),
                                                              linewidths=0.01,
                                                              figsize=(60,15),
                                                              linecolor='black',
                                                              method='complete')

# %%
motif_abd_table.shape
# Out:
# (21, 504)
