# %%
#akyork
#written to analyze the 15 HMO glycans provided by Ben


import sys
import __init__
import json_utility
from glypy.io import glycoct
from extract_motif import get_motif_pip
from customize_motif_vec import merge_motif_dict_pipe, motif_matching_wrapper
import customize_motif_vec

from importlib import reload

# %%
#run motif search on 15 HMO glycans

#loads the json into dictionary form
hmo_dict = json_utility.load_json("/Users/apple/PycharmProjects/GlyCompare/generated_json_file/glycanHMO_dict.json")

#turns hmo dict to glycoCT dict
hmoCT_dict = {}
for items in hmo_dict.items():
    hmoCT_dict[items[0]] = glycoct.loads(items[1])

#gets motifs and saves to json file
hmoMotif_dict = get_motif_pip(hmoCT_dict, gly_len=22, output_file="/Users/apple/PycharmProjects/GlyCompare/generated_json_file/glycanHMO_motif_dict.json")
hmoMotif_dict
# Out:
# start parallel
# 3 0.011188030242919922
# 3 0.01121211051940918
# 3 0.013204097747802734
# 4 0.022166013717651367
# 4 0.01843404769897461
# 5 0.04843306541442871
# 5 0.03938579559326172
# 5 0.05360984802246094
# 6 0.08116316795349121
# 6 0.10032987594604492
# 5 0.027785778045654297
# 5 0.031291961669921875
# 7 0.11166501045227051
# closing poll
# joining pool
# 8 0.21804308891296387
# 8 0.1963038444519043
# finished pool
# {'G01650PH': {'1': [RES
#    1b:x-dglc-HEX-1:5
#    LIN, RES
#    1b:a-lgal-HEX-1:5|6:d
#    LIN, RES
#    1b:b-dgal-HEX-1:5
#    LIN, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    LIN
#    1:1d(2+1)2n, RES
#    1b:b-dgal-HEX-1:5
#    LIN], '2': [RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d, RES
#    1b:b-dgal-HEX-1:5
#    2b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(2+1)2d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:b-dgal-HEX-1:5
#    LIN
#    1:1d(2+1)2n
#    2:1o(3+1)3d], '3': [RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:b-dgal-HEX-1:5
#    4b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1d(2+1)2n
#    2:1o(3+1)3d
#    3:3o(2+1)4d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d], '4': [RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:4o(2+1)5d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d]}, 'G06210XB': {'1': [RES
#    1b:a-lgal-HEX-1:5|6:d
#    LIN, RES
#    1b:b-dgal-HEX-1:5
#    LIN, RES
#    1b:x-dglc-HEX-1:5
#    LIN], '2': [RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d, RES
#    1b:x-dglc-HEX-1:5
#    2b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(3+1)2d]}, 'G10422IZ': {'1': [RES
#    1b:x-dglc-HEX-1:5
#    LIN, RES
#    1b:a-lgal-HEX-1:5|6:d
#    LIN, RES
#    1b:b-dgal-HEX-1:5
#    LIN], '2': [RES
#    1b:b-dgal-HEX-1:5
#    2b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(2+1)2d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d]}, 'G19017MP': {'1': [RES
#    1b:x-dglc-HEX-1:5
#    LIN, RES
#    1b:b-dgal-HEX-1:5
#    LIN, RES
#    1b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    2s:n-acetyl
#    LIN
#    1:1d(5+1)2n, RES
#    1b:b-dgal-HEX-1:5
#    LIN, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    LIN
#    1:1d(2+1)2n], '2': [RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    4s:n-acetyl
#    LIN
#    1:1d(2+1)2n
#    2:1o(6+2)3d
#    3:3d(5+1)4n, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:b-dgal-HEX-1:5
#    LIN
#    1:1d(2+1)2n
#    2:1o(3+1)3d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n], '3': [RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:b-dgal-HEX-1:5
#    4b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    5s:n-acetyl
#    LIN
#    1:1d(2+1)2n
#    2:1o(3+1)3d
#    3:1o(6+2)4d
#    4:4d(5+1)5n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    5s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(6+2)4d
#    4:4d(5+1)5n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n], '4': [RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    6s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:2o(6+2)5d
#    5:5d(5+1)6n, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    6s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(6+2)5d
#    5:5d(5+1)6n, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d]}, 'G24504JY': {'1': [RES
#    1b:x-dglc-HEX-1:5
#    LIN, RES
#    1b:b-dgal-HEX-1:5
#    LIN, RES
#    1b:a-lgal-HEX-1:5|6:d
#    LIN, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    LIN
#    1:1d(2+1)2n, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    LIN
#    1:1d(2+1)2n, RES
#    1b:b-dgal-HEX-1:5
#    LIN, RES
#    1b:b-dgal-HEX-1:5
#    LIN], '2': [RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:b-dgal-HEX-1:5
#    LIN
#    1:1d(2+1)2n
#    2:1o(4+1)3d, RES
#    1b:b-dgal-HEX-1:5
#    2b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(2+1)2d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:b-dgal-HEX-1:5
#    LIN
#    1:1d(2+1)2n
#    2:1o(3+1)3d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    LIN
#    1:1o(6+1)2d
#    2:2d(2+1)3n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n], '3': [RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:b-dgal-HEX-1:5
#    4b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1d(2+1)2n
#    2:1o(3+1)3d
#    3:3o(2+1)4d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    LIN
#    1:1o(6+1)2d
#    2:2d(2+1)3n
#    3:2o(4+1)4d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(6+1)3d
#    3:3d(2+1)4n, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dglc-HEX-1:5
#    5s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:1o(6+1)4d
#    4:4d(2+1)5n], '4': [RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(6+1)3d
#    3:3d(2+1)4n
#    4:3o(4+1)5d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:4o(2+1)5d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dglc-HEX-1:5
#    5s:n-acetyl
#    6b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:1o(6+1)4d
#    4:4d(2+1)5n
#    5:4o(4+1)6d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dglc-HEX-1:5
#    6s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:2o(6+1)5d
#    5:5d(2+1)6n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:b-dglc-HEX-1:5
#    6s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:1o(6+1)5d
#    5:5d(2+1)6n], '5': [RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    6b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d
#    5:5o(2+1)6d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dglc-HEX-1:5
#    6s:n-acetyl
#    7b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:2o(6+1)5d
#    5:5d(2+1)6n
#    6:5o(4+1)7d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:a-lgal-HEX-1:5|6:d
#    6b:b-dglc-HEX-1:5
#    7s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:4o(2+1)5d
#    5:1o(6+1)6d
#    6:6d(2+1)7n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:b-dglc-HEX-1:5
#    6s:n-acetyl
#    7b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:1o(6+1)5d
#    5:5d(2+1)6n
#    6:5o(4+1)7d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    6b:b-dglc-HEX-1:5
#    7s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d
#    5:2o(6+1)6d
#    6:6d(2+1)7n], '6': [RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:a-lgal-HEX-1:5|6:d
#    6b:b-dglc-HEX-1:5
#    7s:n-acetyl
#    8b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:4o(2+1)5d
#    5:1o(6+1)6d
#    6:6d(2+1)7n
#    7:6o(4+1)8d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    6b:a-lgal-HEX-1:5|6:d
#    7b:b-dglc-HEX-1:5
#    8s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d
#    5:5o(2+1)6d
#    6:2o(6+1)7d
#    7:7d(2+1)8n, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    6b:b-dglc-HEX-1:5
#    7s:n-acetyl
#    8b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d
#    5:2o(6+1)6d
#    6:6d(2+1)7n
#    7:6o(4+1)8d]}, 'G38710SX': {'1': [RES
#    1b:x-dglc-HEX-1:5
#    LIN, RES
#    1b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    2s:n-acetyl
#    LIN
#    1:1d(5+1)2n, RES
#    1b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    2s:n-acetyl
#    LIN
#    1:1d(5+1)2n, RES
#    1b:b-dgal-HEX-1:5
#    LIN, RES
#    1b:b-dgal-HEX-1:5
#    LIN, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    LIN
#    1:1d(2+1)2n], '2': [RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d, RES
#    1b:b-dgal-HEX-1:5
#    2b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    3s:n-acetyl
#    LIN
#    1:1o(3+2)2d
#    2:2d(5+1)3n, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    4s:n-acetyl
#    LIN
#    1:1d(2+1)2n
#    2:1o(6+2)3d
#    3:3d(5+1)4n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:b-dgal-HEX-1:5
#    LIN
#    1:1d(2+1)2n
#    2:1o(3+1)3d], '3': [RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    5s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(6+2)4d
#    4:4d(5+1)5n, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:b-dgal-HEX-1:5
#    4b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    5s:n-acetyl
#    LIN
#    1:1d(2+1)2n
#    2:1o(3+1)3d
#    3:3o(3+2)4d
#    4:4d(5+1)5n, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:b-dgal-HEX-1:5
#    4b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    5s:n-acetyl
#    LIN
#    1:1d(2+1)2n
#    2:1o(3+1)3d
#    3:1o(6+2)4d
#    4:4d(5+1)5n, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d], '4': [RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:b-dgal-HEX-1:5
#    4b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    5s:n-acetyl
#    6b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    7s:n-acetyl
#    LIN
#    1:1d(2+1)2n
#    2:1o(3+1)3d
#    3:3o(3+2)4d
#    4:4d(5+1)5n
#    5:1o(6+2)6d
#    6:6d(5+1)7n, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    6s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(6+2)5d
#    5:5d(5+1)6n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    6s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:4o(3+2)5d
#    5:5d(5+1)6n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    6s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:2o(6+2)5d
#    5:5d(5+1)6n, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d], '5': [RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    6s:n-acetyl
#    7b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    8s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:4o(3+2)5d
#    5:5d(5+1)6n
#    6:2o(6+2)7d
#    7:7d(5+1)8n, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    6b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    7s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d
#    5:5o(3+2)6d
#    6:6d(5+1)7n, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    6b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    7s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d
#    5:3o(6+2)6d
#    6:6d(5+1)7n]}, 'G45827GY': {'1': [RES
#    1b:x-dglc-HEX-1:5
#    LIN, RES
#    1b:b-dgal-HEX-1:5
#    LIN, RES
#    1b:b-dgal-HEX-1:5
#    LIN, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    LIN
#    1:1d(2+1)2n], '2': [RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:b-dgal-HEX-1:5
#    LIN
#    1:1d(2+1)2n
#    2:1o(3+1)3d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n], '3': [RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n]}, 'G47928KI': {'1': [RES
#    1b:x-dglc-HEX-1:5
#    LIN, RES
#    1b:b-dgal-HEX-1:5
#    LIN, RES
#    1b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    2s:n-acetyl
#    LIN
#    1:1d(5+1)2n, RES
#    1b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    2s:n-acetyl
#    LIN
#    1:1d(5+1)2n, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    LIN
#    1:1d(2+1)2n, RES
#    1b:b-dgal-HEX-1:5
#    LIN, RES
#    1b:b-dgal-HEX-1:5
#    LIN, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    LIN
#    1:1d(2+1)2n], '2': [RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:b-dgal-HEX-1:5
#    LIN
#    1:1d(2+1)2n
#    2:1o(4+1)3d, RES
#    1b:b-dgal-HEX-1:5
#    2b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    3s:n-acetyl
#    LIN
#    1:1o(3+2)2d
#    2:2d(5+1)3n, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    4s:n-acetyl
#    LIN
#    1:1d(2+1)2n
#    2:1o(6+2)3d
#    3:3d(5+1)4n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    LIN
#    1:1o(6+1)2d
#    2:2d(2+1)3n, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:b-dgal-HEX-1:5
#    LIN
#    1:1d(2+1)2n
#    2:1o(3+1)3d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n], '3': [RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    LIN
#    1:1o(6+1)2d
#    2:2d(2+1)3n
#    3:2o(4+1)4d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(6+1)3d
#    3:3d(2+1)4n, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:b-dgal-HEX-1:5
#    4b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    5s:n-acetyl
#    LIN
#    1:1d(2+1)2n
#    2:1o(3+1)3d
#    3:3o(3+2)4d
#    4:4d(5+1)5n, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:b-dgal-HEX-1:5
#    4b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    5s:n-acetyl
#    LIN
#    1:1d(2+1)2n
#    2:1o(3+1)3d
#    3:1o(6+2)4d
#    4:4d(5+1)5n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    5s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(6+2)4d
#    4:4d(5+1)5n, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dglc-HEX-1:5
#    5s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:1o(6+1)4d
#    4:4d(2+1)5n], '4': [RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(6+1)3d
#    3:3d(2+1)4n
#    4:3o(4+1)5d, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:b-dgal-HEX-1:5
#    4b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    5s:n-acetyl
#    6b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    7s:n-acetyl
#    LIN
#    1:1d(2+1)2n
#    2:1o(3+1)3d
#    3:3o(3+2)4d
#    4:4d(5+1)5n
#    5:1o(6+2)6d
#    6:6d(5+1)7n, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    6s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(6+2)5d
#    5:5d(5+1)6n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    6s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:4o(3+2)5d
#    5:5d(5+1)6n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    6s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:2o(6+2)5d
#    5:5d(5+1)6n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    5s:n-acetyl
#    6b:b-dglc-HEX-1:5
#    7s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(6+2)4d
#    4:4d(5+1)5n
#    5:1o(6+1)6d
#    6:6d(2+1)7n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dglc-HEX-1:5
#    5s:n-acetyl
#    6b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:1o(6+1)4d
#    4:4d(2+1)5n
#    5:4o(4+1)6d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dglc-HEX-1:5
#    6s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:2o(6+1)5d
#    5:5d(2+1)6n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:b-dglc-HEX-1:5
#    6s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:1o(6+1)5d
#    5:5d(2+1)6n], '5': [RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    6s:n-acetyl
#    7b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    8s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:4o(3+2)5d
#    5:5d(5+1)6n
#    6:2o(6+2)7d
#    7:7d(5+1)8n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    5s:n-acetyl
#    6b:b-dglc-HEX-1:5
#    7s:n-acetyl
#    8b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(6+2)4d
#    4:4d(5+1)5n
#    5:1o(6+1)6d
#    6:6d(2+1)7n
#    7:6o(4+1)8d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    6b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    7s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d
#    5:5o(3+2)6d
#    6:6d(5+1)7n, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    6b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    7s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d
#    5:3o(6+2)6d
#    6:6d(5+1)7n, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    6s:n-acetyl
#    7b:b-dglc-HEX-1:5
#    8s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(6+2)5d
#    5:5d(5+1)6n
#    6:2o(6+1)7d
#    7:7d(2+1)8n, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dglc-HEX-1:5
#    6s:n-acetyl
#    7b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:2o(6+1)5d
#    5:5d(2+1)6n
#    6:5o(4+1)7d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    6s:n-acetyl
#    7b:b-dglc-HEX-1:5
#    8s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:4o(3+2)5d
#    5:5d(5+1)6n
#    6:1o(6+1)7d
#    7:7d(2+1)8n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    6s:n-acetyl
#    7b:b-dglc-HEX-1:5
#    8s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:2o(6+2)5d
#    5:5d(5+1)6n
#    6:1o(6+1)7d
#    7:7d(2+1)8n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:b-dglc-HEX-1:5
#    6s:n-acetyl
#    7b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:1o(6+1)5d
#    5:5d(2+1)6n
#    6:5o(4+1)7d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    6b:b-dglc-HEX-1:5
#    7s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d
#    5:2o(6+1)6d
#    6:6d(2+1)7n], '6': [RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    6b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    7s:n-acetyl
#    8b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    9s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d
#    5:5o(3+2)6d
#    6:6d(5+1)7n
#    7:3o(6+2)8d
#    8:8d(5+1)9n, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    6s:n-acetyl
#    7b:b-dglc-HEX-1:5
#    8s:n-acetyl
#    9b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(6+2)5d
#    5:5d(5+1)6n
#    6:2o(6+1)7d
#    7:7d(2+1)8n
#    8:7o(4+1)9d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    6s:n-acetyl
#    7b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    8s:n-acetyl
#    9b:b-dglc-HEX-1:5
#    10s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:4o(3+2)5d
#    5:5d(5+1)6n
#    6:2o(6+2)7d
#    7:7d(5+1)8n
#    8:1o(6+1)9d
#    9:9d(2+1)10n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    6s:n-acetyl
#    7b:b-dglc-HEX-1:5
#    8s:n-acetyl
#    9b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:4o(3+2)5d
#    5:5d(5+1)6n
#    6:1o(6+1)7d
#    7:7d(2+1)8n
#    8:7o(4+1)9d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    6s:n-acetyl
#    7b:b-dglc-HEX-1:5
#    8s:n-acetyl
#    9b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:2o(6+2)5d
#    5:5d(5+1)6n
#    6:1o(6+1)7d
#    7:7d(2+1)8n
#    8:7o(4+1)9d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    6b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    7s:n-acetyl
#    8b:b-dglc-HEX-1:5
#    9s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d
#    5:5o(3+2)6d
#    6:6d(5+1)7n
#    7:2o(6+1)8d
#    8:8d(2+1)9n, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    6b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    7s:n-acetyl
#    8b:b-dglc-HEX-1:5
#    9s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d
#    5:3o(6+2)6d
#    6:6d(5+1)7n
#    7:2o(6+1)8d
#    8:8d(2+1)9n, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    6b:b-dglc-HEX-1:5
#    7s:n-acetyl
#    8b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d
#    5:2o(6+1)6d
#    6:6d(2+1)7n
#    7:6o(4+1)8d], '7': [RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    6s:n-acetyl
#    7b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    8s:n-acetyl
#    9b:b-dglc-HEX-1:5
#    10s:n-acetyl
#    11b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:4o(3+2)5d
#    5:5d(5+1)6n
#    6:2o(6+2)7d
#    7:7d(5+1)8n
#    8:1o(6+1)9d
#    9:9d(2+1)10n
#    10:9o(4+1)11d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    6b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    7s:n-acetyl
#    8b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    9s:n-acetyl
#    10b:b-dglc-HEX-1:5
#    11s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d
#    5:5o(3+2)6d
#    6:6d(5+1)7n
#    7:3o(6+2)8d
#    8:8d(5+1)9n
#    9:2o(6+1)10d
#    10:10d(2+1)11n, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    6b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    7s:n-acetyl
#    8b:b-dglc-HEX-1:5
#    9s:n-acetyl
#    10b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d
#    5:5o(3+2)6d
#    6:6d(5+1)7n
#    7:2o(6+1)8d
#    8:8d(2+1)9n
#    9:8o(4+1)10d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    6b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    7s:n-acetyl
#    8b:b-dglc-HEX-1:5
#    9s:n-acetyl
#    10b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d
#    5:3o(6+2)6d
#    6:6d(5+1)7n
#    7:2o(6+1)8d
#    8:8d(2+1)9n
#    9:8o(4+1)10d]}, 'G48059CD': {'1': [RES
#    1b:x-dglc-HEX-1:5
#    LIN, RES
#    1b:b-dgal-HEX-1:5
#    LIN, RES
#    1b:b-dgal-HEX-1:5
#    LIN, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    LIN
#    1:1d(2+1)2n], '2': [RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:b-dgal-HEX-1:5
#    LIN
#    1:1d(2+1)2n
#    2:1o(4+1)3d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n], '3': [RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(4+1)4d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n]}, 'G63053GR': {'1': [RES
#    1b:x-dglc-HEX-1:5
#    LIN, RES
#    1b:a-lgal-HEX-1:5|6:d
#    LIN, RES
#    1b:b-dgal-HEX-1:5
#    LIN, RES
#    1b:a-lgal-HEX-1:5|6:d
#    LIN, RES
#    1b:b-dgal-HEX-1:5
#    LIN, RES
#    1b:b-dgal-HEX-1:5
#    LIN, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    LIN
#    1:1d(2+1)2n, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    LIN
#    1:1d(2+1)2n], '2': [RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:b-dgal-HEX-1:5
#    LIN
#    1:1d(2+1)2n
#    2:1o(4+1)3d, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1d(2+1)2n
#    2:1o(3+1)3d, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:b-dgal-HEX-1:5
#    LIN
#    1:1d(2+1)2n
#    2:1o(4+1)3d, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1d(2+1)2n
#    2:1o(3+1)3d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    LIN
#    1:1o(6+1)2d
#    2:2d(2+1)3n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n], '3': [RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:a-lgal-HEX-1:5|6:d
#    4b:b-dgal-HEX-1:5
#    LIN
#    1:1d(2+1)2n
#    2:1o(3+1)3d
#    3:1o(4+1)4d, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:a-lgal-HEX-1:5|6:d
#    4b:b-dgal-HEX-1:5
#    LIN
#    1:1d(2+1)2n
#    2:1o(3+1)3d
#    3:1o(4+1)4d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    LIN
#    1:1o(6+1)2d
#    2:2d(2+1)3n
#    3:2o(4+1)4d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(6+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(4+1)4d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(6+1)3d
#    3:3d(2+1)4n, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dglc-HEX-1:5
#    5s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:1o(6+1)4d
#    4:4d(2+1)5n], '4': [RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:a-lgal-HEX-1:5|6:d
#    5b:b-dgal-HEX-1:5
#    LIN
#    1:1o(6+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:2o(4+1)5d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:a-lgal-HEX-1:5|6:d
#    5b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:2o(4+1)5d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(6+1)3d
#    3:3d(2+1)4n
#    4:3o(4+1)5d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(4+1)2d
#    2:2o(6+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(4+1)5d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:b-dglc-HEX-1:5
#    6s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(4+1)4d
#    4:1o(6+1)5d
#    5:5d(2+1)6n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:a-lgal-HEX-1:5|6:d
#    5b:b-dglc-HEX-1:5
#    6s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:1o(6+1)5d
#    5:5d(2+1)6n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dglc-HEX-1:5
#    5s:n-acetyl
#    6b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:1o(6+1)4d
#    4:4d(2+1)5n
#    5:4o(4+1)6d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dglc-HEX-1:5
#    5s:n-acetyl
#    6b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:1o(6+1)4d
#    4:4d(2+1)5n
#    5:4o(3+1)6d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dglc-HEX-1:5
#    6s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:2o(6+1)5d
#    5:5d(2+1)6n], '5': [RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:a-lgal-HEX-1:5|6:d
#    6b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(6+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d
#    5:3o(4+1)6d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:a-lgal-HEX-1:5|6:d
#    6b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d
#    5:3o(4+1)6d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:a-lgal-HEX-1:5|6:d
#    5b:b-dgal-HEX-1:5
#    6b:b-dglc-HEX-1:5
#    7s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:2o(4+1)5d
#    5:1o(6+1)6d
#    6:6d(2+1)7n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:b-dglc-HEX-1:5
#    6s:n-acetyl
#    7b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(4+1)4d
#    4:1o(6+1)5d
#    5:5d(2+1)6n
#    6:5o(4+1)7d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:a-lgal-HEX-1:5|6:d
#    5b:b-dglc-HEX-1:5
#    6s:n-acetyl
#    7b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:1o(6+1)5d
#    5:5d(2+1)6n
#    6:5o(4+1)7d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:b-dglc-HEX-1:5
#    6s:n-acetyl
#    7b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(4+1)4d
#    4:1o(6+1)5d
#    5:5d(2+1)6n
#    6:5o(3+1)7d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:a-lgal-HEX-1:5|6:d
#    5b:b-dglc-HEX-1:5
#    6s:n-acetyl
#    7b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:1o(6+1)5d
#    5:5d(2+1)6n
#    6:5o(3+1)7d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dglc-HEX-1:5
#    5s:n-acetyl
#    6b:a-lgal-HEX-1:5|6:d
#    7b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:1o(6+1)4d
#    4:4d(2+1)5n
#    5:4o(3+1)6d
#    6:4o(4+1)7d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    6b:b-dglc-HEX-1:5
#    7s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(4+1)5d
#    5:2o(6+1)6d
#    6:6d(2+1)7n, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:a-lgal-HEX-1:5|6:d
#    6b:b-dglc-HEX-1:5
#    7s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d
#    5:2o(6+1)6d
#    6:6d(2+1)7n, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dglc-HEX-1:5
#    6s:n-acetyl
#    7b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:2o(6+1)5d
#    5:5d(2+1)6n
#    6:5o(4+1)7d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dglc-HEX-1:5
#    6s:n-acetyl
#    7b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:2o(6+1)5d
#    5:5d(2+1)6n
#    6:5o(3+1)7d], '6': [RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:a-lgal-HEX-1:5|6:d
#    5b:b-dgal-HEX-1:5
#    6b:b-dglc-HEX-1:5
#    7s:n-acetyl
#    8b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:2o(4+1)5d
#    5:1o(6+1)6d
#    6:6d(2+1)7n
#    7:6o(4+1)8d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:a-lgal-HEX-1:5|6:d
#    5b:b-dgal-HEX-1:5
#    6b:b-dglc-HEX-1:5
#    7s:n-acetyl
#    8b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:2o(4+1)5d
#    5:1o(6+1)6d
#    6:6d(2+1)7n
#    7:6o(3+1)8d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:b-dglc-HEX-1:5
#    6s:n-acetyl
#    7b:a-lgal-HEX-1:5|6:d
#    8b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(4+1)4d
#    4:1o(6+1)5d
#    5:5d(2+1)6n
#    6:5o(3+1)7d
#    7:5o(4+1)8d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:a-lgal-HEX-1:5|6:d
#    5b:b-dglc-HEX-1:5
#    6s:n-acetyl
#    7b:a-lgal-HEX-1:5|6:d
#    8b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:1o(6+1)5d
#    5:5d(2+1)6n
#    6:5o(3+1)7d
#    7:5o(4+1)8d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:a-lgal-HEX-1:5|6:d
#    6b:b-dgal-HEX-1:5
#    7b:b-dglc-HEX-1:5
#    8s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d
#    5:3o(4+1)6d
#    6:2o(6+1)7d
#    7:7d(2+1)8n, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    6b:b-dglc-HEX-1:5
#    7s:n-acetyl
#    8b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(4+1)5d
#    5:2o(6+1)6d
#    6:6d(2+1)7n
#    7:6o(4+1)8d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:a-lgal-HEX-1:5|6:d
#    6b:b-dglc-HEX-1:5
#    7s:n-acetyl
#    8b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d
#    5:2o(6+1)6d
#    6:6d(2+1)7n
#    7:6o(4+1)8d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    6b:b-dglc-HEX-1:5
#    7s:n-acetyl
#    8b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(4+1)5d
#    5:2o(6+1)6d
#    6:6d(2+1)7n
#    7:6o(3+1)8d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:a-lgal-HEX-1:5|6:d
#    6b:b-dglc-HEX-1:5
#    7s:n-acetyl
#    8b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d
#    5:2o(6+1)6d
#    6:6d(2+1)7n
#    7:6o(3+1)8d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dglc-HEX-1:5
#    6s:n-acetyl
#    7b:a-lgal-HEX-1:5|6:d
#    8b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:2o(6+1)5d
#    5:5d(2+1)6n
#    6:5o(3+1)7d
#    7:5o(4+1)8d], '7': [RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:a-lgal-HEX-1:5|6:d
#    5b:b-dgal-HEX-1:5
#    6b:b-dglc-HEX-1:5
#    7s:n-acetyl
#    8b:a-lgal-HEX-1:5|6:d
#    9b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:2o(4+1)5d
#    5:1o(6+1)6d
#    6:6d(2+1)7n
#    7:6o(3+1)8d
#    8:6o(4+1)9d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:a-lgal-HEX-1:5|6:d
#    6b:b-dgal-HEX-1:5
#    7b:b-dglc-HEX-1:5
#    8s:n-acetyl
#    9b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d
#    5:3o(4+1)6d
#    6:2o(6+1)7d
#    7:7d(2+1)8n
#    8:7o(4+1)9d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:a-lgal-HEX-1:5|6:d
#    6b:b-dgal-HEX-1:5
#    7b:b-dglc-HEX-1:5
#    8s:n-acetyl
#    9b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d
#    5:3o(4+1)6d
#    6:2o(6+1)7d
#    7:7d(2+1)8n
#    8:7o(3+1)9d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    6b:b-dglc-HEX-1:5
#    7s:n-acetyl
#    8b:a-lgal-HEX-1:5|6:d
#    9b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(4+1)5d
#    5:2o(6+1)6d
#    6:6d(2+1)7n
#    7:6o(3+1)8d
#    8:6o(4+1)9d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:a-lgal-HEX-1:5|6:d
#    6b:b-dglc-HEX-1:5
#    7s:n-acetyl
#    8b:a-lgal-HEX-1:5|6:d
#    9b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d
#    5:2o(6+1)6d
#    6:6d(2+1)7n
#    7:6o(3+1)8d
#    8:6o(4+1)9d]}, 'G70115XG': {'1': [RES
#    1b:a-lgal-HEX-1:5|6:d
#    LIN, RES
#    1b:b-dgal-HEX-1:5
#    LIN, RES
#    1b:a-lgal-HEX-1:5|6:d
#    LIN, RES
#    1b:x-dglc-HEX-1:5
#    LIN, RES
#    1b:b-dgal-HEX-1:5
#    LIN, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    LIN
#    1:1d(2+1)2n], '2': [RES
#    1b:x-dglc-HEX-1:5
#    2b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(3+1)2d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1d(2+1)2n
#    2:1o(4+1)3d, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:b-dgal-HEX-1:5
#    LIN
#    1:1d(2+1)2n
#    2:1o(3+1)3d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n], '3': [RES
#    1b:x-dglc-HEX-1:5
#    2b:a-lgal-HEX-1:5|6:d
#    3b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:1o(4+1)3d, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:b-dgal-HEX-1:5
#    4b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1d(2+1)2n
#    2:1o(3+1)3d
#    3:1o(4+1)4d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(4+1)4d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n], '4': [RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:2o(4+1)5d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(4+1)5d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d, RES
#    1b:x-dglc-HEX-1:5
#    2b:a-lgal-HEX-1:5|6:d
#    3b:b-dgal-HEX-1:5
#    4b:b-dglc-HEX-1:5
#    5s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:1o(4+1)3d
#    3:3o(3+1)4d
#    4:4d(2+1)5n], '5': [RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    6b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d
#    5:3o(4+1)6d, RES
#    1b:x-dglc-HEX-1:5
#    2b:a-lgal-HEX-1:5|6:d
#    3b:b-dgal-HEX-1:5
#    4b:b-dglc-HEX-1:5
#    5s:n-acetyl
#    6b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(3+1)2d
#    2:1o(4+1)3d
#    3:3o(3+1)4d
#    4:4d(2+1)5n
#    5:4o(4+1)6d, RES
#    1b:x-dglc-HEX-1:5
#    2b:a-lgal-HEX-1:5|6:d
#    3b:b-dgal-HEX-1:5
#    4b:b-dglc-HEX-1:5
#    5s:n-acetyl
#    6b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:1o(4+1)3d
#    3:3o(3+1)4d
#    4:4d(2+1)5n
#    5:4o(3+1)6d]}, 'G72506RN': {'1': [RES
#    1b:x-dglc-HEX-1:5
#    LIN, RES
#    1b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    2s:n-acetyl
#    LIN
#    1:1d(5+1)2n, RES
#    1b:b-dgal-HEX-1:5
#    LIN, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    LIN
#    1:1d(2+1)2n, RES
#    1b:b-dgal-HEX-1:5
#    LIN], '2': [RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d, RES
#    1b:b-dgal-HEX-1:5
#    2b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    3s:n-acetyl
#    LIN
#    1:1o(6+2)2d
#    2:2d(5+1)3n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:b-dgal-HEX-1:5
#    LIN
#    1:1d(2+1)2n
#    2:1o(4+1)3d], '3': [RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:b-dgal-HEX-1:5
#    4b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    5s:n-acetyl
#    LIN
#    1:1d(2+1)2n
#    2:1o(4+1)3d
#    3:3o(6+2)4d
#    4:4d(5+1)5n, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(4+1)4d], '4': [RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    6s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(4+1)4d
#    4:4o(6+2)5d
#    5:5d(5+1)6n, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(4+1)5d]}, 'G83916HL': {'1': [RES
#    1b:x-dglc-HEX-1:5
#    LIN, RES
#    1b:a-lgal-HEX-1:5|6:d
#    LIN, RES
#    1b:b-dgal-HEX-1:5
#    LIN, RES
#    1b:b-dgal-HEX-1:5
#    LIN, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    LIN
#    1:1d(2+1)2n], '2': [RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:b-dgal-HEX-1:5
#    LIN
#    1:1d(2+1)2n
#    2:1o(4+1)3d, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1d(2+1)2n
#    2:1o(3+1)3d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n], '3': [RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:a-lgal-HEX-1:5|6:d
#    4b:b-dgal-HEX-1:5
#    LIN
#    1:1d(2+1)2n
#    2:1o(3+1)3d
#    3:1o(4+1)4d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(4+1)4d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n], '4': [RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:a-lgal-HEX-1:5|6:d
#    5b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:2o(4+1)5d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(4+1)5d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d]}, 'G91237TK': {'1': [RES
#    1b:b-dglc-HEX-1:5
#    LIN, RES
#    1b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    2s:n-acetyl
#    LIN
#    1:1d(5+1)2n, RES
#    1b:b-dgal-HEX-1:5
#    LIN], '2': [RES
#    1b:b-dgal-HEX-1:5
#    2b:a-dgro-dgal-NON-2:6|1:a|2:keto|3:d
#    3s:n-acetyl
#    LIN
#    1:1o(3+2)2d
#    2:2d(5+1)3n, RES
#    1b:b-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d]}, 'G98173LG': {'1': [RES
#    1b:x-dglc-HEX-1:5
#    LIN, RES
#    1b:b-dgal-HEX-1:5
#    LIN, RES
#    1b:a-lgal-HEX-1:5|6:d
#    LIN, RES
#    1b:b-dgal-HEX-1:5
#    LIN, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    LIN
#    1:1d(2+1)2n], '2': [RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1d(2+1)2n
#    2:1o(4+1)3d, RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:b-dgal-HEX-1:5
#    LIN
#    1:1d(2+1)2n
#    2:1o(3+1)3d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n], '3': [RES
#    1b:b-dglc-HEX-1:5
#    2s:n-acetyl
#    3b:b-dgal-HEX-1:5
#    4b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1d(2+1)2n
#    2:1o(3+1)3d
#    3:1o(4+1)4d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(4+1)4d, RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n], '4': [RES
#    1b:b-dgal-HEX-1:5
#    2b:b-dglc-HEX-1:5
#    3s:n-acetyl
#    4b:b-dgal-HEX-1:5
#    5b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(3+1)2d
#    2:2d(2+1)3n
#    3:2o(3+1)4d
#    4:2o(4+1)5d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:a-lgal-HEX-1:5|6:d
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(4+1)5d, RES
#    1b:x-dglc-HEX-1:5
#    2b:b-dgal-HEX-1:5
#    3b:b-dglc-HEX-1:5
#    4s:n-acetyl
#    5b:b-dgal-HEX-1:5
#    LIN
#    1:1o(4+1)2d
#    2:2o(3+1)3d
#    3:3d(2+1)4n
#    4:3o(3+1)5d]}}

# %%
import multiprocessing

merge_motif_dict_pipe(hmoMotif_dict, '/Users/apple/PycharmProjects/GlyCompare/generated_json_file/merged_motif_HMO')
#key changed to integer not string
# Out:
# Start merge_glycan_motif_to_motif_dict
# check merged motif vec len 306
# get_motif_dict_degree_list_pipe
# closing poll
# joining pool
# finished removing duplicate
# after the cleaning the motif vec's length is 76
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-01514c3e936e> in <module>()
#       1 import multiprocessing
#       2
# ----> 3 merge_motif_dict_pipe(hmoMotif_dict, '/Users/apple/PycharmProjects/GlyCompare/generated_json_file/merged_motif_HMO')
#       4 #key changed to integer not string
#
# ~/PycharmProjects/GlyCompare/src/customize_motif_vec.py in merge_motif_dict_pipe(glycan_dict, output_merged_motif_dict_addr)
#     164     # print(motif_dict.keys())
#     165     for i in sorted_len_motif_degree:
# --> 166         print(i, len(motif_dict[int(i)]))
#     167         motif_dict_str[i] = [str(j) for j in motif_dict[i]]
#     168     store_json(output_merged_motif_dict_addr, motif_dict_str)
#
# KeyError: 1

# %%
motif_matching_wrapper(hmoMotif_dict, hmoMotif_dict, __init__.output_matched_dict_addr)
# Out:
# G01650PH 4
# G06210XB 2
# G10422IZ 2
# G19017MP 4
# G24504JY 6
# G38710SX 5
# G45827GY 3
# G47928KI 7
# G48059CD 3
# G63053GR 7
# G70115XG 5
# G72506RN 4
# G83916HL 4
# G91237TK 2
# G98173LG 4
# 62
# get motif vec, the length is  62
# error 0
# error 1
# finished  0
# finished  1
# error 2
# finished  2
# error 3
# finished  3
# error 5
# finished  5
# error 6
# finished  6
# error 4
# finished  4
# error 7
# finished  7
# error 8
# finished  8
# error 9
# finished  9
# error 10
# finished  10
# error 11
# finished  11
# start processing G45827GY
# start processing G48059CD
# start processing G10422IZ
# start processing G01650PH
# start processing G98173LG
# start processing G06210XB
# start processing G91237TK
# start processing G83916HL
# start processing G19017MP
# start processing G72506RN
# start processing G38710SX
# start processing G24504JY
# start processing G63053GR
# start processing G70115XG
# start processing G47928KI
# closing poll
# joining pool
# error 13
# finished  13
# error 12
# finished  12
# error 14
# finished  14
# converting dict
# {}

# %%
match_motif()
