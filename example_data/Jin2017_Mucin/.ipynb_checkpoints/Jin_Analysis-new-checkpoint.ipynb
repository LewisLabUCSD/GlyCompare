# %%
library(ggplot2)
library(gplots)
library("viridis")   
library('rjson')
library(reshape2)
library(broom)
library('jsonlite')
library(reticulate)
# Out:
# Error in library(reticulate): there is no package called ‘reticulate’
# Traceback:
#
# 1. library(reticulate)

# %%
# # install.packages("rjson")
# install.packages("tidyverse")

# # alternatively, to install just broom:
# # install.packages("broom")

# # # to get the development version from GitHub:
# # install.packages("devtools")
install.packages("reticulate")
# Out:
# The downloaded binary packages are in
# 	/var/folders/r7/f70_k76n3sv5hl_s70c_cb4w0000gn/T//RtmpsegrCF/downloaded_packages

# %%
glycan_abd = t(read.csv('data-in/structural/paper_mcp_abundance_table.csv',row.names = 1))
rownames(glycan_abd) = gsub('^X','',rownames(glycan_abd))
motif_abd = t(t(read.csv('data-in/structural/Jin_2017_motif_abd_table.new.csv',row.names=1)))
samp_annot = read.csv('data-in/structural//paper_mcp_sample_annotation.csv')
var_annot = read.csv('data-in/structural//paper_mcp_variable_annotation.csv')

head(glycan_abd)
head(motif_abd)
head(samp_annot)
head(var_annot)

all(colnames(glycan_abd)==colnames(motif_abd))
all(colnames(glycan_abd)==samp_annot$Sample)
# Out:
#       P1TS         P1TI      P3TS      P2TS        P4TS      P4TI     P6TA_FS
# 384    0.200000000 2.0602903 0.0000000  1.72229021  1.478829 0.000000 3.5044604
# 425_1  0.000000000 0.2002307 0.0000000  0.09552175  0.000000 0.000000 0.1593463
# 425_2  0.005744057 0.0000000 0.0000000  0.00000000  0.000000 0.000000 0.0526829
# 513    0.665288490 3.2947108 0.0000000 10.62497071 11.257345 0.000000 0.3080759
# 530   12.541670010 8.6044105 5.2276773  3.31270949  5.993043 7.902581 2.2808420
# 587_1  0.280895309 3.1717004 0.4782521  2.20448505  2.405548 1.632434 1.6922025
#       P6TA_FG    P6TA_AS    P6TA_AG  P5TA_AS     P5TA_AG  P7TA_AS   P7TA_AG
# 384    1.3199561  0.0000000 0.000000  2.02765796 0.000000  0.000000 0.0000000
# 425_1  0.0000000  0.0000000 0.000000  0.07283916 0.000000  0.000000 0.0000000
# 425_2  0.0000000  0.0000000 0.000000  0.13150272 0.000000  0.000000 0.0000000
# 513    0.4763836  0.0000000 0.000000 12.45581407 0.000000  0.000000 0.2772022
# 530   11.6963219 11.9652210 6.578836  4.11436871 6.278508 13.208941 7.5290292
# 587_1  0.7805676  0.6827428 1.932521  9.00689343 0.000000  6.807255 0.1432739
#       P8H        P9H       P10H
# 384    2.2940523 0.0000000 0.9421212
# 425_1  0.0000000 0.0000000 0.1352820
# 425_2  0.1319171 0.0000000 0.1447573
# 513    0.8661203 1.3405621 2.1754509
# 530   12.0219205 1.8505313 8.4560704
# 587_1  2.1557202 0.5498721 2.2253434
#        P1TS        P1TI        P3TS        P2TS        P4TS        P4TI
# L26801 0.803558464 0.629315292 0.578143329 0.512444226 0.440878882 0.858601338
# L26802 0.989017492 0.902026097 0.967427652 0.837724000 0.856350857 0.972248985
# L26805 0.002905366 0.057981740 0.004075797 0.030422142 0.017940536 0.014083457
# L26808 0.006241664 0.010551218 0.049165773 0.092943165 0.195441667 0.000000000
# L26812 0.020889952 0.087367761 0.021602132 0.242281440 0.197735161 0.004633522
# L26817 0.001146570 0.003482617 0.006668421 0.002544619 0.003510924 0.013667557
#        P6TA.FS     P6TA.FG     P6TA.AS    P6TA.AG    P5TA.AS      P5TA.AG
# L26801 0.831737719 0.770856762 0.79112186 0.85319551 0.6097661528 0.68833068
# L26802 0.960109001 0.959014258 0.96689641 1.00000000 0.8545102915 0.87673239
# L26805 0.034579424 0.036221906 0.03310359 0.00000000 0.0117654867 0.10245589
# L26808 0.002797119 0.002937426 0.01263713 0.00000000 0.0074108654 0.00000000
# L26812 0.020139985 0.009826390 0.00461705 0.02700506 0.3008704549 0.00000000
# L26817 0.006749115 0.000000000 0.00000000 0.00000000 0.0006611563 0.02081173
#        P7TA.AS   P7TA.AG     P8H         P9H        P10H
# L26801 0.5314634 0.819944612 0.773685311 0.93201081 0.754372769
# L26802 1.0000000 0.993570380 0.968558847 0.98654532 0.943127410
# L26805 0.0000000 0.003657598 0.019423688 0.00000000 0.029498626
# L26808 0.3364472 0.003896883 0.003505325 0.00000000 0.007839022
# L26812 0.0000000 0.008012952 0.024990253 0.02534702 0.083437399
# L26817 0.0000000 0.000000000 0.005808702 0.00000000 0.001823987
#   Sample Specimen Disease Extraction Tissue Subtype Location
# 1 P1TS   1        Tumor   Soluble    Tumor  Tumor
# 2 P1TI   1        Tumor   Insoluble  Tumor  Tumor
# 3 P3TS   3        Tumor   Soluble    Tumor  Tumor
# 4 P2TS   2        Tumor   Soluble    Tumor  Tumor
# 5 P4TS   4        Tumor   Soluble    Tumor  Tumor
# 6 P4TI   4        Tumor   Insoluble  Tumor  Tumor
#   Unnamed..0 m.z Composition
# 1 0          384 Hex(1)HexNAc(1)
# 2 1          425 HexNAc(2)
# 3 2          425 HexNAc(2)
# 4 3          513 NeuAc(1)HexNAc(1)
# 5 4          530 Hex(1)HexNAc(1)dHex(1)
# 6 5          587 Hex(1)HexNAc(2)
#   Glycan.Structure
# 1 RES\n1b:x_dgal_HEX_x:x\n2s:n_acetyl\n3b:b_dgal_HEX_x:x\nLIN\n1:1d(2+1)2n\n2:1o(3+1)3d\n
# 2 RES\n1b:x_dgal_HEX_x:x\n2s:n_acetyl\n3b:b_dglc_HEX_x:x\n4s:n_acetyl\nLIN\n1:1d(2+1)2n\n2:1o(3+1)3d\n3:3d(2+1)4n\n
# 3 RES\n1b:x_dgal_HEX_x:x\n2s:n_acetyl\n3b:a_dgal_HEX_x:x\n4s:n_acetyl\nLIN\n1:1d(2+1)2n\n2:1o(3+1)3d\n3:3d(2+1)4n\n
# 4 RES\n1b:x_dgal_HEX_x:x\n2s:n_acetyl\n3b:a_dgro_dgal_NON_x:x|1:a|2:keto|3:d\n4s:n_acetyl\nLIN\n1:1d(2+1)2n\n2:1o(6+2)3d\n3:3d(5+1)4n\n
# 5 RES\n1b:x_dgal_HEX_x:x\n2s:n_acetyl\n3b:b_dgal_HEX_x:x\n4b:a_lgal_HEX_x:x|6:d\nLIN\n1:1d(2+1)2n\n2:1o(3+1)3d\n3:3o(2+1)4d\n
# 6 RES\n1b:x_dgal_HEX_x:x\n2s:n_acetyl\n3b:b_dgal_HEX_x:x\n4b:b_dglc_HEX_x:x\n5s:n_acetyl\nLIN\n1:1d(2+1)2n\n2:1o(3+1)3d\n3:1o(6+1)4d\n4:4d(2+1)5n\n
#   Name
# 1 384
# 2 425_1
# 3 425_2
# 4 513
# 5 530
# 6 587_1
#   Glycoprofiles
# 1 ['P1TS', 'P1TI', 'P2TS', 'P4TS', 'P6TA_FS', 'P6TA_FG', 'P5TA_AS', 'P8H', 'P10H']
# 2 ['P1TI', 'P2TS', 'P6TA_FS', 'P5TA_AS', 'P10H']
# 3 ['P1TS', 'P6TA_FS', 'P5TA_AS', 'P8H', 'P10H']
# 4 ['P1TS', 'P1TI', 'P2TS', 'P4TS', 'P6TA_FS', 'P6TA_FG', 'P5TA_AS', 'P7TA_AG', 'P8H', 'P9H', 'P10H']
# 5 ['P1TS', 'P1TI', 'P3TS', 'P2TS', 'P4TS', 'P4TI', 'P6TA_FS', 'P6TA_FG', 'P6TA_AS', 'P6TA_AG', 'P5TA_AS', 'P5TA_AG', 'P7TA_AS', 'P7TA_AG', 'P8H', 'P9H', 'P10H']
# 6 ['P1TS', 'P1TI', 'P3TS', 'P2TS', 'P4TS', 'P4TI', 'P6TA_FS', 'P6TA_FG', 'P6TA_AS', 'P6TA_AG', 'P5TA_AS', 'P7TA_AS', 'P7TA_AG', 'P8H', 'P9H', 'P10H']
# [1] FALSE
# [1] TRUE
# Error in fromJSON(file = "../unicarb_substructures.linkSpecific.merged_reference_dict_28779_2020-09-10_00_53_50.json"): argument "txt" is missing, with no default
# Traceback:
#
# 1. fromJSON(file = "../unicarb_substructures.linkSpecific.merged_reference_dict_28779_2020-09-10_00_53_50.json")

# %%
motif_vect = fromJSON(txt='../unicarb_substructures.linkSpecific.merged_reference_dict_28779_2020-09-10_00_53_50.json')
motif_vect=melt(motif_vect)
head(motif_vect)
# Out:
#   value
# 1 L0
# 2 L1
# 3 L2
# 4 L3
# 5 L4
# 6 L5
#   L1
# 1 RES\n1b:a-lgal-HEX-1:5|6:d\nLIN\n
# 2 RES\n1b:b-dgal-HEX-1:5\n2s:sulfate\nLIN\n1:1o(3+1)2n\n
# 3 RES\n1b:b-dglc-HEX-1:5\n2s:n-acetyl\nLIN\n1:1d(2+1)2n\n
# 4 RES\n1b:a-dman-HEX-1:5\nLIN\n
# 5 RES\n1b:b-dman-HEX-1:5\nLIN\n
# 6 RES\n1b:x-dgro-dgal-NON-2:6|1:a|2:keto|3:d\n2s:n-acetyl\nLIN\n1:1d(5+1)2n\n

# %%
for(i in 1:2){
    if(i==1){pdf('results/structures_per_profile.pdf')}
    par(mfrow = c(2,1))
    hist(apply(glycan_abd,1,function(x) sum(x>0)),breaks=seq(0,17,1))
    hist(apply(motif_abd,1,function(x) sum(x>0)),breaks=seq(0,17,1))
    if(i==1){dev.off()}
}
# Out:
# Plot with title “Histogram of apply(motif_abd, 1, function(x) sum(x > 0))”

# %% [markdown]
# ### figure 7

# %%
min_nz=1
p_glycan=as.data.frame(do.call(rbind,apply(log(glycan_abd[idx<-apply(glycan_abd,1,function(x) sum(x>0)>min_nz),]+1),1,
           function(x) tidy(t.test(x[samp_annot$Disease=='Tumor'],x[samp_annot$Disease=='Normal'])))))
rownames(p_glycan) = rownames(glycan_abd)[idx]
                                                       
p_motif=as.data.frame(do.call(rbind,apply(log(motif_abd[idx<-apply(motif_abd,1,function(x) sum(x>0)>min_nz),]+.001),1,function(x){
    out=NA
    try(out<-tidy(t.test(x[samp_annot$Disease=='Tumor'],x[samp_annot$Disease=='Normal'])))
    return(out)
    })))
rownames(p_motif) = rownames(motif_abd)[idx]

#head(p_motif)
p_glycan$fdr=p.adjust(p_glycan$p.value,'fdr')
p_motif$fdr=p.adjust(p_motif$p.value,'fdr')
                                                                
p_glycan$logFC = log2((exp(p_glycan$estimate1)-.001)/(exp(p_glycan$estimate2)-.001))
p_motif$logFC = log2((exp(p_motif$estimate1)-.001)/(exp(p_motif$estimate2)-.001))

write.table(p_glycan, file="results/figure7.glycan.csv",sep=',')
write.table(p_motif, file="results/figure7.motif.csv",sep=',')                    
                                                                   
for(i in 1:2){
    if(i==2){pdf('results/significance.pdf')}
    par(mfrow = c(2,2))
    hist(p_glycan$p.value,main='Glycan P-values',breaks=seq(0,1,.1),ylim=c(0,90))
    hist(p_glycan$fdr,main='Glycan FDR',breaks=seq(0,1,.1),ylim=c(0,150))
    hist(p_motif$p.value,main='Motif P-values',breaks=seq(0,1,.1),ylim=c(0,90))
    hist(p_motif$fdr,main='Motif FDR',breaks=seq(0,1,.1),ylim=c(0,150))
    if(i==2){dev.off()}
}
    
p_motif=na.omit(p_motif)   
sel_motifs = rownames(p_motif)[idx<-p_motif$fdr<.1]
out=cbind(p_motif[idx,c('logFC','estimate','estimate1','estimate2','statistic','p.value','fdr')],iupac=do.call(rbind,lapply(sel_motifs,function(x){
    library(reticulate)
    glypy <- import('glypy')
    glypy$io$iupac$dumps(glypy$io$glycoct$loads(motif_vect$L1[motif_vect$value==x]))
})))
write.table(out$iupac,row.names = F)
write.table(cbind(signif(out[,c('logFC','fdr','estimate1','estimate2')],3),out$iupac),row.names = F)
# Out:
# Error in t.test.default(x[samp_annot$Disease == "Tumor"], x[samp_annot$Disease ==  :
#   data are essentially constant
# Error in t.test.default(x[samp_annot$Disease == "Tumor"], x[samp_annot$Disease ==  :
#   data are essentially constant
# Error in t.test.default(x[samp_annot$Disease == "Tumor"], x[samp_annot$Disease ==  :
#   data are essentially constant
# "x"
# "?-D-Galx-(1-?)-?-D-Glcx2NAc-(1-?)-b-D-Galx-(1-3)-?-D-Galx2NAc"
# "?-L-Fucx-(1-?)-?-D-Glcx2NAc-(1-?)-b-D-Galx-(1-3)-?-D-Galx2NAc"
# "b-D-Glcx2NAc-(1-6)-[?-D-Galx-(1-?)-?-D-Glcx2NAc-(1-?)-b-D-Galx-(1-3)]?-D-Galx2NAc"
# "b-D-Glcx2NAc-(1-6)-[?-L-Fucx-(1-?)-?-D-Glcx2NAc-(1-?)-b-D-Galx-(1-3)]?-D-Galx2NAc"
# "?-D-Galx-(1-?)-?-D-Glcx2NAc-(1-?)-[?-D-Galx-(1-?)-?-D-Glcx2NAc-(1-?)]b-D-Galx-(1-3)-?-D-Galx2NAc"
# "b-D-Galx-(1-4)-b-D-Glcx2NAc-(1-6)-[?-L-Fucx-(1-?)-?-D-Glcx2NAc-(1-?)-b-D-Galx-(1-3)]?-D-Galx2NAc"
# "a-L-Fucx-(1-2)-?-D-Galx-(1-?)-?-D-Glcx2NAc-(1-?)-[?-D-Galx-(1-?)-?-D-Glcx2NAc-(1-?)]b-D-Galx-(1-3)-?-D-Galx2NAc"
# "b-D-Glcx2NAc-(1-6)-[?-D-Galx-(1-?)-?-D-Glcx2NAc-(1-?)-[?-D-Galx-(1-?)-?-D-Glcx2NAc-(1-?)]b-D-Galx-(1-3)]?-D-Galx2NAc"
# "b-D-Glcx2NAc-(1-6)-[a-L-Fucx-(1-2)-?-D-Galx-(1-?)-?-D-Glcx2NAc-(1-?)-[?-D-Galx-(1-?)-?-D-Glcx2NAc-(1-?)]b-D-Galx-(1-3)]?-D-Galx2NAc"
# "logFC" "fdr" "estimate1" "estimate2" "out$iupac"
# -3.79 0.0965 -6.06 -3.93 "?-D-Galx-(1-?)-?-D-Glcx2NAc-(1-?)-b-D-Galx-(1-3)-?-D-Galx2NAc"
# -4.51 0.0916 -6.49 -4.36 "?-L-Fucx-(1-?)-?-D-Glcx2NAc-(1-?)-b-D-Galx-(1-3)-?-D-Galx2NAc"
# -4.03 0.0713 -6.18 -3.99 "b-D-Glcx2NAc-(1-6)-[?-D-Galx-(1-?)-?-D-Glcx2NAc-(1-?)-b-D-Galx-(1-3)]?-D-Galx2NAc"
# -5.02 0.0713 -6.61 -4.41 "b-D-Glcx2NAc-(1-6)-[?-L-Fucx-(1-?)-?-D-Glcx2NAc-(1-?)-b-D-Galx-(1-3)]?-D-Galx2NAc"
# -3.79 0.0965 -6.06 -3.93 "?-D-Galx-(1-?)-?-D-Glcx2NAc-(1-?)-[?-D-Galx-(1-?)-?-D-Glcx2NAc-(1-?)]b-D-Galx-(1-3)-?-D-Galx2NAc"
# -5.57 0.000418 -6.82 -5.22 "b-D-Galx-(1-4)-b-D-Glcx2NAc-(1-6)-[?-L-Fucx-(1-?)-?-D-Glcx2NAc-(1-?)-b-D-Galx-(1-3)]?-D-Galx2NAc"
# -4.47 0.0916 -6.58 -4.64 "a-L-Fucx-(1-2)-?-D-Galx-(1-?)-?-D-Glcx2NAc-(1-?)-[?-D-Galx-(1-?)-?-D-Glcx2NAc-(1-?)]b-D-Galx-(1-3)-?-D-Galx2NAc"
# -3.89 0.0713 -6.18 -4.08 "b-D-Glcx2NAc-(1-6)-[?-D-Galx-(1-?)-?-D-Glcx2NAc-(1-?)-[?-D-Galx-(1-?)-?-D-Glcx2NAc-(1-?)]b-D-Galx-(1-3)]?-D-Galx2NAc"
# -5.06 0.0228 -6.7 -4.75 "b-D-Glcx2NAc-(1-6)-[a-L-Fucx-(1-2)-?-D-Galx-(1-?)-?-D-Glcx2NAc-(1-?)-[?-D-Galx-(1-?)-?-D-Glcx2NAc-(1-?)]b-D-Galx-(1-3)]?-D-Galx2NAc"
# Plot with title “Motif FDR”

# %%
options(repr.plot.width=12, repr.plot.height=12)

heatmap.2(log2(glycan_abd+1),trace='none',col=colorspace::diverge_hsv,scale='row',ColSideColors = c('red','blue','white')[samp_annot$Disease])
heatmap.2(log2(motif_abd+.01),trace='none',col=colorspace::diverge_hsv,scale='row',ColSideColors = c('red','blue','white')[samp_annot$Disease])

heatmap.2(cor(log2(glycan_abd+1))^2,trace='none',col=inferno,ColSideColors = c('red','blue','white')[samp_annot$Disease])
heatmap.2(cor(log2(motif_abd+.01))^2,trace='none',col=inferno,ColSideColors = c('red','blue','white')[samp_annot$Disease])

# heatmap.2(unique(log2(glycan_abd[apply(glycan_abd,1,sum)>1,]+1)),trace='none',col=viridis,scale = 'row')
# heatmap.2(unique(log2(motif_abd[apply(motif_abd,1,sum)>.1,]+.01)),trace='none',col=viridis,scale='row')
# Out:
# Plot with title “Color Key
# and Histogram”
# Plot with title “Color Key
# and Histogram”
# Plot with title “Color Key
# and Histogram”
# Plot with title “Color Key
# and Histogram”

# %%
samp_annot$Disease
# Out:
#  [1] Tumor         Tumor         Tumor         Tumor         Tumor
#  [6] Tumor         TumorAdjacent TumorAdjacent TumorAdjacent TumorAdjacent
# [11] TumorAdjacent TumorAdjacent TumorAdjacent TumorAdjacent Normal
# [16] Normal        Normal
# Levels: Normal Tumor TumorAdjacent
